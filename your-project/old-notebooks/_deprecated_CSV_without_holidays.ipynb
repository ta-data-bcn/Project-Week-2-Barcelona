# %%
import pandas as pd
import numpy as np
import os

# %%
full_csv = pd.read_csv("datasets/1.-Transportation/accidents-2017.csv")
full_csv
# Out:
#                     Id District Name           Neighborhood Name  \
# 0      2017S008429           Unknown                     Unknown
# 1      2017S007316           Unknown                     Unknown
# 2      2017S010210           Unknown                     Unknown
# 3      2017S006364           Unknown                     Unknown
# 4      2017S004615        Sant Martí  el Camp de l'Arpa del Clot
# ...                ...           ...                         ...
# 10334  2017S003667       Sant Andreu               el Bon Pastor
# 10335  2017S001896       Sant Andreu               el Bon Pastor
# 10336  2017S010718       Sant Andreu               el Bon Pastor
# 10337  2017S006145       Sant Andreu               el Bon Pastor
# 10338  2017S000178       Sant Andreu               el Bon Pastor
#
#                                                   Street    Weekday  \
# 0      Número 27                                     ...     Friday
# ...

# %%
difference = 10339 - len_total
difference
# Out:
# 9983

# %%
len_total = len1 + len2 + len3 + len4 + len5 + len6 + len7 + len8
len_total
# Out:
# 356

# %%
len1 = len(full_csv[(full_csv["Month"] == "June") & (full_csv["Day"].isin([23, 24]))])
len1
# Out:
# 38

# %%
#San Juan Deleted
first_update = full_csv.drop(full_csv[(full_csv["Month"] == "June") & (full_csv["Day"].isin([23, 24]))].index)
first_update
# Out:
#                     Id District Name           Neighborhood Name  \
# 0      2017S008429           Unknown                     Unknown
# 1      2017S007316           Unknown                     Unknown
# 2      2017S010210           Unknown                     Unknown
# 3      2017S006364           Unknown                     Unknown
# 4      2017S004615        Sant Martí  el Camp de l'Arpa del Clot
# ...                ...           ...                         ...
# 10334  2017S003667       Sant Andreu               el Bon Pastor
# 10335  2017S001896       Sant Andreu               el Bon Pastor
# 10336  2017S010718       Sant Andreu               el Bon Pastor
# 10337  2017S006145       Sant Andreu               el Bon Pastor
# 10338  2017S000178       Sant Andreu               el Bon Pastor
#
#                                                   Street    Weekday  \
# 0      Número 27                                     ...     Friday
# ...

# %%
len2 = len(first_update[(first_update["Month"] == "September") & (first_update["Day"].isin([22, 23, 24, 25]))])
len2
# Out:
# 95

# %%
#Merce Deleted
second_update = first_update.drop(first_update[(first_update["Month"] == "September") & (first_update["Day"].isin([22, 23, 24, 25]))].index)
second_update
# Out:
#                     Id District Name           Neighborhood Name  \
# 0      2017S008429           Unknown                     Unknown
# 1      2017S007316           Unknown                     Unknown
# 2      2017S010210           Unknown                     Unknown
# 3      2017S006364           Unknown                     Unknown
# 4      2017S004615        Sant Martí  el Camp de l'Arpa del Clot
# ...                ...           ...                         ...
# 10334  2017S003667       Sant Andreu               el Bon Pastor
# 10335  2017S001896       Sant Andreu               el Bon Pastor
# 10336  2017S010718       Sant Andreu               el Bon Pastor
# 10337  2017S006145       Sant Andreu               el Bon Pastor
# 10338  2017S000178       Sant Andreu               el Bon Pastor
#
#                                                   Street    Weekday  \
# 0      Número 27                                     ...     Friday
# ...

# %%
len3 = len(second_update[(second_update["Month"] == "December") & (second_update["Day"].isin([24, 25]))])
len3
# Out:
# 30

# %%
#Christmas Deleted
third_update = second_update.drop(second_update[(second_update["Month"] == "December") & (second_update["Day"].isin([24, 25]))].index)
third_update
# Out:
#                     Id District Name           Neighborhood Name  \
# 0      2017S008429           Unknown                     Unknown
# 1      2017S007316           Unknown                     Unknown
# 2      2017S010210           Unknown                     Unknown
# 3      2017S006364           Unknown                     Unknown
# 4      2017S004615        Sant Martí  el Camp de l'Arpa del Clot
# ...                ...           ...                         ...
# 10334  2017S003667       Sant Andreu               el Bon Pastor
# 10335  2017S001896       Sant Andreu               el Bon Pastor
# 10336  2017S010718       Sant Andreu               el Bon Pastor
# 10337  2017S006145       Sant Andreu               el Bon Pastor
# 10338  2017S000178       Sant Andreu               el Bon Pastor
#
#                                                   Street    Weekday  \
# 0      Número 27                                     ...     Friday
# ...

# %%
len4 = len(third_update[(third_update["Month"] == "December") & (third_update["Day"].isin([6, 7, 8]))])
len4
# Out:
# 35

# %%
#December holiday 6-8 Deleted
fourth_update = third_update.drop(third_update[(third_update["Month"] == "December") & (third_update["Day"].isin([6, 7, 8]))].index)
fourth_update
# Out:
#                     Id District Name           Neighborhood Name  \
# 0      2017S008429           Unknown                     Unknown
# 1      2017S007316           Unknown                     Unknown
# 3      2017S006364           Unknown                     Unknown
# 4      2017S004615        Sant Martí  el Camp de l'Arpa del Clot
# 5      2017S007775        Sant Martí  el Camp de l'Arpa del Clot
# ...                ...           ...                         ...
# 10334  2017S003667       Sant Andreu               el Bon Pastor
# 10335  2017S001896       Sant Andreu               el Bon Pastor
# 10336  2017S010718       Sant Andreu               el Bon Pastor
# 10337  2017S006145       Sant Andreu               el Bon Pastor
# 10338  2017S000178       Sant Andreu               el Bon Pastor
#
#                                                   Street    Weekday  \
# 0      Número 27                                     ...     Friday
# ...

# %%
len5 = len(fourth_update[(fourth_update["Month"] == "April") & (fourth_update["Day"].isin([14, 15, 16, 17]))])
len5
# Out:
# 60

# %%
#Holy Week Deleted
fifth_update = fourth_update.drop(fourth_update[(fourth_update["Month"] == "April") & (fourth_update["Day"].isin([14, 15, 16, 17]))].index)
fifth_update
# Out:
#                     Id District Name           Neighborhood Name  \
# 0      2017S008429           Unknown                     Unknown
# 1      2017S007316           Unknown                     Unknown
# 3      2017S006364           Unknown                     Unknown
# 4      2017S004615        Sant Martí  el Camp de l'Arpa del Clot
# 5      2017S007775        Sant Martí  el Camp de l'Arpa del Clot
# ...                ...           ...                         ...
# 10334  2017S003667       Sant Andreu               el Bon Pastor
# 10335  2017S001896       Sant Andreu               el Bon Pastor
# 10336  2017S010718       Sant Andreu               el Bon Pastor
# 10337  2017S006145       Sant Andreu               el Bon Pastor
# 10338  2017S000178       Sant Andreu               el Bon Pastor
#
#                                                   Street    Weekday  \
# 0      Número 27                                     ...     Friday
# ...

# %%
len6 = len(fifth_update[(fifth_update["Month"] == "September") & (fifth_update["Day"].isin([8, 9, 10, 11]))])
len6
# Out:
# 69

# %%
#Day of Catalonia
sixth_update = fifth_update.drop(fifth_update[(fifth_update["Month"] == "September") & (fifth_update["Day"].isin([8, 9, 10, 11]))].index)
sixth_update
# Out:
#                     Id District Name           Neighborhood Name  \
# 0      2017S008429           Unknown                     Unknown
# 1      2017S007316           Unknown                     Unknown
# 3      2017S006364           Unknown                     Unknown
# 4      2017S004615        Sant Martí  el Camp de l'Arpa del Clot
# 5      2017S007775        Sant Martí  el Camp de l'Arpa del Clot
# ...                ...           ...                         ...
# 10334  2017S003667       Sant Andreu               el Bon Pastor
# 10335  2017S001896       Sant Andreu               el Bon Pastor
# 10336  2017S010718       Sant Andreu               el Bon Pastor
# 10337  2017S006145       Sant Andreu               el Bon Pastor
# 10338  2017S000178       Sant Andreu               el Bon Pastor
#
#                                                   Street    Weekday  \
# 0      Número 27                                     ...     Friday
# ...

# %%
len7 = len(sixth_update[(sixth_update["Month"] == "December") & (sixth_update["Day"].isin([31]))])
len7
# Out:
# 7

# %%
#NYE Deleted
sevent_update = sixth_update.drop(sixth_update[(sixth_update["Month"] == "December") & (sixth_update["Day"].isin([31]))].index)
sevent_update
# Out:
#                     Id District Name           Neighborhood Name  \
# 0      2017S008429           Unknown                     Unknown
# 1      2017S007316           Unknown                     Unknown
# 3      2017S006364           Unknown                     Unknown
# 4      2017S004615        Sant Martí  el Camp de l'Arpa del Clot
# 5      2017S007775        Sant Martí  el Camp de l'Arpa del Clot
# ...                ...           ...                         ...
# 10334  2017S003667       Sant Andreu               el Bon Pastor
# 10335  2017S001896       Sant Andreu               el Bon Pastor
# 10336  2017S010718       Sant Andreu               el Bon Pastor
# 10337  2017S006145       Sant Andreu               el Bon Pastor
# 10338  2017S000178       Sant Andreu               el Bon Pastor
#
#                                                   Street    Weekday  \
# 0      Número 27                                     ...     Friday
# ...

# %%
len8 = len(sevent_update[(sevent_update["Month"] == "January") & (sevent_update["Day"].isin([1]))])
len8
# Out:
# 22

# %%
#NY Deleted
eight_update = sevent_update.drop(sevent_update[(sevent_update["Month"] == "January") & (sevent_update["Day"].isin([1]))].index)
eight_update
# Out:
#                     Id District Name           Neighborhood Name  \
# 0      2017S008429           Unknown                     Unknown
# 1      2017S007316           Unknown                     Unknown
# 3      2017S006364           Unknown                     Unknown
# 4      2017S004615        Sant Martí  el Camp de l'Arpa del Clot
# 5      2017S007775        Sant Martí  el Camp de l'Arpa del Clot
# ...                ...           ...                         ...
# 10334  2017S003667       Sant Andreu               el Bon Pastor
# 10335  2017S001896       Sant Andreu               el Bon Pastor
# 10336  2017S010718       Sant Andreu               el Bon Pastor
# 10337  2017S006145       Sant Andreu               el Bon Pastor
# 10338  2017S000178       Sant Andreu               el Bon Pastor
#
#                                                   Street    Weekday  \
# 0      Número 27                                     ...     Friday
# ...

# %%
new_update = eight_update
new_update
len(new_update)
# Out:
# 9983

# %%
#3King Deleted
new_update1 = new_update.drop(new_update[(new_update["Month"] == "January") & (new_update["Day"].isin([6, 7]))].index)
len(new_update1)
# Out:
# 9948

# %%
#1stMay LW. Part1
new_update2 = new_update1.drop(new_update1[(new_update1["Month"] == "April") & (new_update1["Day"].isin([28, 29, 30]))].index)
len(new_update2)
# Out:
# 9878

# %%
#1stMay LW. Part2
new_update3 = new_update2.drop(new_update2[(new_update2["Month"] == "May") & (new_update2["Day"].isin([1]))].index)
len(new_update3)
# Out:
# 9865

# %%
#2nd Monday of Easter
new_update4 = new_update3.drop(new_update3[(new_update3["Month"] == "June") & (new_update3["Day"].isin([2, 3, 4, 5]))].index)
len(new_update4)
# Out:
# 9771

# %%
#15th August
new_update5 = new_update4.drop(new_update4[(new_update4["Month"] == "August") & (new_update4["Day"].isin([15]))].index)
len(new_update5)
# Out:
# 9758

# %%
#12th October
new_update6 = new_update5.drop(new_update5[(new_update5["Month"] == "October") & (new_update5["Day"].isin([12]))].index)
len(new_update6)
# Out:
# 9741

# %%
#1th November
new_update7 = new_update6.drop(new_update6[(new_update6["Month"] == "November") & (new_update6["Day"].isin([1]))].index)
len(new_update7)
# Out:
# 9731

# %%
#St Esteve
new_update8 = new_update7.drop(new_update7[(new_update7["Month"] == "December") & (new_update7["Day"].isin([26]))].index)
len(new_update8)
# Out:
# 9707

# %%
#St Jordi
new_update9 = new_update8.drop(new_update8[(new_update8["Month"] == "April") & (new_update8["Day"].isin([23]))].index)
len(new_update9)
# Out:
# 9691

# %%
#St Valentines
new_update10 = new_update9.drop(new_update9[(new_update9["Month"] == "February") & (new_update9["Day"].isin([14]))].index)
len(new_update10)
# Out:
# 9651

# %%
file_updated = new_update10

# %%
file_updated
# Out:
#                     Id District Name           Neighborhood Name  \
# 0      2017S008429           Unknown                     Unknown
# 1      2017S007316           Unknown                     Unknown
# 3      2017S006364           Unknown                     Unknown
# 4      2017S004615        Sant Martí  el Camp de l'Arpa del Clot
# 5      2017S007775        Sant Martí  el Camp de l'Arpa del Clot
# ...                ...           ...                         ...
# 10334  2017S003667       Sant Andreu               el Bon Pastor
# 10335  2017S001896       Sant Andreu               el Bon Pastor
# 10336  2017S010718       Sant Andreu               el Bon Pastor
# 10337  2017S006145       Sant Andreu               el Bon Pastor
# 10338  2017S000178       Sant Andreu               el Bon Pastor
#
#                                                   Street    Weekday  \
# 0      Número 27                                     ...     Friday
# ...

# %%
file_updated.drop(["Id", "Neighborhood Name", "Street", "Hour", "Longitude", "Latitude"], axis=1, inplace=True)

# %%
file_updated
# Out:
#       District Name    Weekday      Month  Day Part of the day  Mild injuries  \
# 0           Unknown     Friday    October   13         Morning              2
# 1           Unknown     Friday  September    1         Morning              2
# 3           Unknown     Friday       July   21           Night              1
# 4        Sant Martí   Thursday        May   25       Afternoon              1
# 5        Sant Martí  Wednesday  September   20         Morning              1
# ...             ...        ...        ...  ...             ...            ...
# 10334   Sant Andreu    Tuesday      April   25         Morning              1
# 10335   Sant Andreu  Wednesday      March    8         Morning              1
# 10336   Sant Andreu   Thursday   December   28         Morning              1
# 10337   Sant Andreu     Friday       July   14       Afternoon              1
# 10338   Sant Andreu     Sunday    January    8       Afternoon              0
#
# ...

# %%
file_updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9983 entries, 0 to 10338
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   District Name      9983 non-null   object
#  1   Weekday            9983 non-null   object
#  2   Month              9983 non-null   object
#  3   Day                9983 non-null   int64
#  4   Part of the day    9983 non-null   object
#  5   Mild injuries      9983 non-null   int64
#  6   Serious injuries   9983 non-null   int64
#  7   Victims            9983 non-null   int64
#  8   Vehicles involved  9983 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 779.9+ KB

# %%
august = file_updated[file_updated["Month"] == "August"]

# %%
august
# Out:
#       District Name   Weekday   Month  Day Part of the day  Mild injuries  \
# 30       Sant Martí  Thursday  August   31       Afternoon              0
# 31       Sant Martí   Tuesday  August   15       Afternoon              1
# 34       Sant Martí  Thursday  August   31         Morning              2
# 39       Sant Martí   Tuesday  August    1       Afternoon              1
# 57       Sant Martí   Tuesday  August    8           Night              1
# ...             ...       ...     ...  ...             ...            ...
# 10243    Nou Barris   Tuesday  August    8       Afternoon              1
# 10264   Sant Andreu  Thursday  August   31         Morning              1
# 10278   Sant Andreu    Sunday  August   27         Morning              2
# 10288   Sant Andreu    Monday  August    7       Afternoon              1
# 10311   Sant Andreu    Monday  August   14       Afternoon              1
#
#        Serious injuries  Victims  Vehicles involved
# ...

# %%
file_updated["Month"].value_counts()
# Out:
# November     991
# May          963
# March        935
# October      928
# July         918
# June         870
# February     824
# January      822
# April        785
# December     690
# August       652
# September    605
# Name: Month, dtype: int64

# %%
file_updated.to_csv("datasets/1.-Transportation/accidents-without-holidays_final_version.csv")
