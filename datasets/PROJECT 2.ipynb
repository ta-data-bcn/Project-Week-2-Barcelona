# %%
import pandas as pd

# %%
nationality = pd.read_csv('/Users/andressalomferrer/Desktop/ironhack/Projects/Project-Week-2-Barcelona/datasets/3.-Population/immigrants-by-nationality.csv')

# %%
nationality
# Out:
#        Year  District Code        District Name  Neighborhood Code  \
# 0      2017              1         Ciutat Vella                  1
# 1      2017              1         Ciutat Vella                  2
# 2      2017              1         Ciutat Vella                  3
# 3      2017              1         Ciutat Vella                  4
# 4      2017              2             Eixample                  5
# 5      2017              2             Eixample                  6
# 6      2017              2             Eixample                  7
# 7      2017              2             Eixample                  8
# 8      2017              2             Eixample                  9
# 9      2017              2             Eixample                 10
# 10     2017              3       Sants-Montjuïc                 11
# 11     2017              3       Sants-Montjuïc                 12
# 12     2017              3       Sants-Montjuïc                 13
# ...

# %%
nationality_2 = nationality[['Year', 'Nationality','Number']]

# %%
nationality_3 = nationality_2.loc[(nationality_2.Year == 2017),]

# %%
nationality_3
# Out:
#        Year     Nationality  Number
# 0      2017           Spain    1109
# 1      2017           Spain     482
# 2      2017           Spain     414
# 3      2017           Spain     537
# 4      2017           Spain     663
# 5      2017           Spain    1181
# 6      2017           Spain    1063
# 7      2017           Spain    1177
# 8      2017           Spain    1593
# 9      2017           Spain     883
# 10     2017           Spain     826
# 11     2017           Spain      23
# 12     2017           Spain     574
# 13     2017           Spain     264
# 14     2017           Spain     410
# 15     2017           Spain     434
# 16     2017           Spain     605
# 17     2017           Spain    1083
# 18     2017           Spain    1027
# 19     2017           Spain     630
# 20     2017           Spain     298
# 21     2017           Spain      91
# 22     2017           Spain     541
# 23     2017           Spain     363
# 24     2017           Spain     587
# ...

# %%
nationality_clean = nationality_3.loc[(nationality_2.Year == 2017),].copy()

# %%
nationality_clean
# Out:
#        Year     Nationality  Number
# 0      2017           Spain    1109
# 1      2017           Spain     482
# 2      2017           Spain     414
# 3      2017           Spain     537
# 4      2017           Spain     663
# 5      2017           Spain    1181
# 6      2017           Spain    1063
# 7      2017           Spain    1177
# 8      2017           Spain    1593
# 9      2017           Spain     883
# 10     2017           Spain     826
# 11     2017           Spain      23
# 12     2017           Spain     574
# 13     2017           Spain     264
# 14     2017           Spain     410
# 15     2017           Spain     434
# 16     2017           Spain     605
# 17     2017           Spain    1083
# 18     2017           Spain    1027
# 19     2017           Spain     630
# 20     2017           Spain     298
# 21     2017           Spain      91
# 22     2017           Spain     541
# 23     2017           Spain     363
# 24     2017           Spain     587
# ...

# %%
age = pd.read_csv('/Users/andressalomferrer/Desktop/ironhack/Projects/Project-Week-2-Barcelona/datasets/3.-Population/immigrants-emigrants-by-age.csv')

# %%
age
# Out:
#       Year  District Code        District Name  Neighborhood Code  \
# 0     2017              1         Ciutat Vella                  1
# 1     2017              1         Ciutat Vella                  2
# 2     2017              1         Ciutat Vella                  3
# 3     2017              1         Ciutat Vella                  4
# 4     2017              2             Eixample                  5
# 5     2017              2             Eixample                  6
# 6     2017              2             Eixample                  7
# 7     2017              2             Eixample                  8
# 8     2017              2             Eixample                  9
# 9     2017              2             Eixample                 10
# 10    2017              3       Sants-Montjuïc                 11
# 11    2017              3       Sants-Montjuïc                 12
# 12    2017              3       Sants-Montjuïc                 13
# ...

# %%
age_2 = age[['Year','Age','Immigrants','Emigrants']]

# %%
age_3 = age_2.loc[(age_2.Year == 2017),]

# %%
age_clean = age_3.loc[(age_2.Year == 2017),].copy()

# %%
age_clean
# Out:
#       Year    Age  Immigrants  Emigrants
# 0     2017    0-4         154        108
# 1     2017    0-4          58         33
# 2     2017    0-4          38         37
# 3     2017    0-4          56         55
# 4     2017    0-4          79         60
# 5     2017    0-4         111         95
# 6     2017    0-4         121         78
# 7     2017    0-4          97         63
# 8     2017    0-4         123        130
# 9     2017    0-4          57         80
# 10    2017    0-4          80         99
# 11    2017    0-4           1          2
# 12    2017    0-4          71         59
# 13    2017    0-4          14         15
# 14    2017    0-4          31         37
# 15    2017    0-4          33         39
# 16    2017    0-4          49         57
# 17    2017    0-4         106         83
# 18    2017    0-4         103         73
# 19    2017    0-4          81         55
# 20    2017    0-4          36         16
# 21    2017    0-4          20         16
# ...

# %%
bydestination = pd.read_csv('/Users/andressalomferrer/Desktop/ironhack/Projects/Project-Week-2-Barcelona/datasets/3.-Population/immigrants-emigrants-by-destination.csv')

# %%
bydestination
# Out:
#                    from                   to  weight
# 0                Abroad            Barcelona   53085
# 1             Andalusia            Barcelona    2416
# 2                Aragon            Barcelona     811
# 3              Asturias            Barcelona     323
# 4      Balearic Islands            Barcelona    1634
# 5             Barcelona               Abroad    5485
# 6             Barcelona            Andalusia    1596
# 7             Barcelona               Aragon     745
# 8             Barcelona             Asturias     204
# 9             Barcelona     Balearic Islands    1428
# 10            Barcelona       Basque Country     475
# 11            Barcelona       Canary Islands     789
# 12            Barcelona            Cantabria     132
# 13            Barcelona     Castile and León     517
# 14            Barcelona   Castilla-La Mancha     347
# 15            Barcelona            Catalonia   35036
# 16            Barcelona                Ceuta      12
# ...

# %%
gender = pd.read_csv('/Users/andressalomferrer/Desktop/ironhack/Projects/Project-Week-2-Barcelona/datasets/3.-Population/immigrants-emigrants-by-sex.csv')

# %%
gender
# Out:
#      Year  District Code        District Name  Neighborhood Code  \
# 0    2017              1         Ciutat Vella                  1
# 1    2017              1         Ciutat Vella                  2
# 2    2017              1         Ciutat Vella                  3
# 3    2017              1         Ciutat Vella                  4
# 4    2017              2             Eixample                  5
# 5    2017              2             Eixample                  6
# 6    2017              2             Eixample                  7
# 7    2017              2             Eixample                  8
# 8    2017              2             Eixample                  9
# 9    2017              2             Eixample                 10
# 10   2017              3       Sants-Montjuïc                 11
# 11   2017              3       Sants-Montjuïc                 12
# 12   2017              3       Sants-Montjuïc                 13
# ...

# %%
population = pd.read_csv('/Users/andressalomferrer/Desktop/ironhack/Projects/Project-Week-2-Barcelona/datasets/3.-Population/population.csv')

# %%
population
# Out:
#        Year  District.Code        District.Name  Neighborhood.Code  \
# 0      2017              1         Ciutat Vella                  1
# 1      2017              1         Ciutat Vella                  2
# 2      2017              1         Ciutat Vella                  3
# 3      2017              1         Ciutat Vella                  4
# 4      2017              2             Eixample                  5
# 5      2017              2             Eixample                  6
# 6      2017              2             Eixample                  7
# 7      2017              2             Eixample                  8
# 8      2017              2             Eixample                  9
# 9      2017              2             Eixample                 10
# 10     2017              3       Sants-Montjuïc                 11
# 11     2017              3       Sants-Montjuïc                 12
# 12     2017              3       Sants-Montjuïc                 13
# ...
