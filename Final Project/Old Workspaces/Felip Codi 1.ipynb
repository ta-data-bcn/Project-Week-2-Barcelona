# %%
import pandas as pd
import numpy as np

# %%
atur_per_sexe = pd.read_csv("2020_Atur_per_sexe.csv")

# %%
atur_per_sexe
# Out:
#        Any  Mes  Codi_Districte Nom_Districte  Codi_Barri  \
# 0     2020    1               1  Ciutat Vella           1
# 1     2020    1               1  Ciutat Vella           2
# 2     2020    1               1  Ciutat Vella           3
# 3     2020    1               1  Ciutat Vella           4
# 4     2020    1               2      Eixample           5
# ...    ...  ...             ...           ...         ...
# 3251  2020   11              10    Sant Martí          70
# 3252  2020   11              10    Sant Martí          71
# 3253  2020   11              10    Sant Martí          72
# 3254  2020   11              10    Sant Martí          73
# 3255  2020   11              99     No consta          99
#
#                                   Nom_Barri   Sexe    Demanda_ocupacio  Nombre
# 0                                  el Raval  Homes      Atur Registrat    1724
# 1                            el Barri Gòtic  Homes      Atur Registrat     491
# ...

# %%
atur_per_sexe["Nombre"].value_counts()
# Out:
# 11      16
# 10      11
# 63      11
# 60      11
# 77      10
#         ..
# 1492     1
# 1490     1
# 1484     1
# 1464     1
# 2043     1
# Name: Nombre, Length: 1368, dtype: int64

# %%
prova1 = pd.atur_per_sexe["Nom_Barri","Demanda_ocupacio"]

prova1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-79be6bfbcbf7> in <module>
# ----> 1 prova1 = pd.atur_per_sexe["Nom_Barri","Demanda_ocupacio"]
#       2
#       3 prova1
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     256             return _SparseArray
#     257
# --> 258         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     259
#     260
#
# AttributeError: module 'pandas' has no attribute 'atur_per_sexe'

# %%
atur_per_edat = pd.read_csv("2020_Pes_del_atur_registrat_sobre_poblacio_16_64_anys.csv")

# %%
atur_per_edat
# Out:
#       Any  Mes  Codi_Districte Nom_Districte  Codi_Barri  \
# 0    2020    1               1  Ciutat Vella           1
# 1    2020    1               1  Ciutat Vella           2
# 2    2020    1               1  Ciutat Vella           3
# 3    2020    1               1  Ciutat Vella           4
# 4    2020    1               2      Eixample           5
# ..    ...  ...             ...           ...         ...
# 798  2020   11              10    Sant Martí          69
# 799  2020   11              10    Sant Martí          70
# 800  2020   11              10    Sant Martí          71
# 801  2020   11              10    Sant Martí          72
# 802  2020   11              10    Sant Martí          73
#
#                                         Nom_Barri  Poblacio_16_64_anys  \
# 0                                        el Raval                36405
# 1                                  el Barri Gòtic                15462
# ...

# %%
col_names = ["Month","Neighorbood_Name","Working_Population","Unemployment_Rate"]

# %%
prova1.columns = (col_names)

prova1
# Out:
#      Month                              Neighorbood_Name  Working_Population  \
# 0        1                                      el Raval               36405
# 1        1                                el Barri Gòtic               15462
# 2        1                                la Barceloneta               11337
# 3        1         Sant Pere, Santa Caterina i la Ribera               17710
# 4        1                                 el Fort Pienc               21844
# ..     ...                                           ...                 ...
# 798     11  Diagonal Mar i el Front Marítim del Poblenou                8858
# 799     11                         el Besòs i el Maresme               16577
# 800     11                       Provençals del Poblenou               14217
# 801     11                      Sant Martí de Provençals               16219
# 802     11                           la Verneda i la Pau               17577
#
#      Unemployment_Rate
# ...

# %%
prova1 = atur_per_edat[["Mes","Nom_Barri","Poblacio_16_64_anys","Pes_atur"]]

prova1
# Out:
#      Mes                                     Nom_Barri  Poblacio_16_64_anys  \
# 0      1                                      el Raval                36405
# 1      1                                el Barri Gòtic                15462
# 2      1                                la Barceloneta                11337
# 3      1         Sant Pere, Santa Caterina i la Ribera                17710
# 4      1                                 el Fort Pienc                21844
# ..   ...                                           ...                  ...
# 798   11  Diagonal Mar i el Front Marítim del Poblenou                 8858
# 799   11                         el Besòs i el Maresme                16577
# 800   11                       Provençals del Poblenou                14217
# 801   11                      Sant Martí de Provençals                16219
# 802   11                           la Verneda i la Pau                17577
#
#      Pes_atur
# 0         8.4
# 1         5.9
# ...

# %%
January = prova1[prova1.Month==1]

January
# Out:
#     Month                              Neighorbood_Name  Working_Population  \
# 0       1                                      el Raval               36405
# 1       1                                el Barri Gòtic               15462
# 2       1                                la Barceloneta               11337
# 3       1         Sant Pere, Santa Caterina i la Ribera               17710
# 4       1                                 el Fort Pienc               21844
# ..    ...                                           ...                 ...
# 68      1  Diagonal Mar i el Front Marítim del Poblenou                8858
# 69      1                         el Besòs i el Maresme               16577
# 70      1                       Provençals del Poblenou               14217
# 71      1                      Sant Martí de Provençals               16219
# 72      1                           la Verneda i la Pau               17577
#
#     Unemployment_Rate
# 0                 8.4
# ...

# %%
January.sort_values(by="Unemployment_Rate",ascending = False)
# Out:
#     Month                       Neighorbood_Name  Working_Population  \
# 54      1                       Ciutat Meridiana                7070
# 52      1                       la Trinitat Nova                5082
# 56      1                      la Trinitat Vella                6917
# 55      1                               Vallbona                 893
# 11      1             la Marina del Prat Vermell                 816
# ..    ...                                    ...                 ...
# 25      1                 Sant Gervasi - Galvany               29773
# 41      1                               la Clota                 479
# 21      1  Vallvidrera, el Tibidabo i les Planes                3121
# 22      1                                 Sarrià               14983
# 20      1                              Pedralbes                7025
#
#     Unemployment_Rate
# 54               13.0
# 52               12.5
# 56               12.3
# 55               11.9
# ...

# %%
Febrer = prova1[prova1.Month==2]

Febrer
# Out:
#      Month                              Neighorbood_Name  Working_Population  \
# 73       2                                      el Raval               36405
# 74       2                                el Barri Gòtic               15462
# 75       2                                la Barceloneta               11337
# 76       2         Sant Pere, Santa Caterina i la Ribera               17710
# 77       2                                 el Fort Pienc               21844
# ..     ...                                           ...                 ...
# 141      2  Diagonal Mar i el Front Marítim del Poblenou                8858
# 142      2                         el Besòs i el Maresme               16577
# 143      2                       Provençals del Poblenou               14217
# 144      2                      Sant Martí de Provençals               16219
# 145      2                           la Verneda i la Pau               17577
#
#      Unemployment_Rate
# ...

# %%
Març = prova1[prova1.Month==3]

Març
# Out:
#      Month                              Neighorbood_Name  Working_Population  \
# 146      3                                      el Raval               36405
# 147      3                                el Barri Gòtic               15462
# 148      3                                la Barceloneta               11337
# 149      3         Sant Pere, Santa Caterina i la Ribera               17710
# 150      3                                 el Fort Pienc               21844
# ..     ...                                           ...                 ...
# 214      3  Diagonal Mar i el Front Marítim del Poblenou                8858
# 215      3                         el Besòs i el Maresme               16577
# 216      3                       Provençals del Poblenou               14217
# 217      3                      Sant Martí de Provençals               16219
# 218      3                           la Verneda i la Pau               17577
#
#      Unemployment_Rate
# ...

# %%
Abril = prova1[prova1.Month==4]

Abril
# Out:
#      Month                              Neighorbood_Name  Working_Population  \
# 219      4                                      el Raval               36405
# 220      4                                el Barri Gòtic               15462
# 221      4                                la Barceloneta               11337
# 222      4         Sant Pere, Santa Caterina i la Ribera               17710
# 223      4                                 el Fort Pienc               21844
# ..     ...                                           ...                 ...
# 287      4  Diagonal Mar i el Front Marítim del Poblenou                8858
# 288      4                         el Besòs i el Maresme               16577
# 289      4                       Provençals del Poblenou               14217
# 290      4                      Sant Martí de Provençals               16219
# 291      4                           la Verneda i la Pau               17577
#
#      Unemployment_Rate
# ...

# %%
Maig = prova1[prova1.Month==5]

Maig
# Out:
#      Month                              Neighorbood_Name  Working_Population  \
# 292      5                                      el Raval               36405
# 293      5                                el Barri Gòtic               15462
# 294      5                                la Barceloneta               11337
# 295      5         Sant Pere, Santa Caterina i la Ribera               17710
# 296      5                                 el Fort Pienc               21844
# ..     ...                                           ...                 ...
# 360      5  Diagonal Mar i el Front Marítim del Poblenou                8858
# 361      5                         el Besòs i el Maresme               16577
# 362      5                       Provençals del Poblenou               14217
# 363      5                      Sant Martí de Provençals               16219
# 364      5                           la Verneda i la Pau               17577
#
#      Unemployment_Rate
# ...

# %%
Juny = prova1[prova1.Month==6]

Juny
# Out:
#      Month                              Neighorbood_Name  Working_Population  \
# 365      6                                      el Raval               36405
# 366      6                                el Barri Gòtic               15462
# 367      6                                la Barceloneta               11337
# 368      6         Sant Pere, Santa Caterina i la Ribera               17710
# 369      6                                 el Fort Pienc               21844
# ..     ...                                           ...                 ...
# 433      6  Diagonal Mar i el Front Marítim del Poblenou                8858
# 434      6                         el Besòs i el Maresme               16577
# 435      6                       Provençals del Poblenou               14217
# 436      6                      Sant Martí de Provençals               16219
# 437      6                           la Verneda i la Pau               17577
#
#      Unemployment_Rate
# ...

# %%
Juliol = prova1[prova1.Month==7]

Juliol
# Out:
#      Month                              Neighorbood_Name  Working_Population  \
# 438      7                                      el Raval               36405
# 439      7                                el Barri Gòtic               15462
# 440      7                                la Barceloneta               11337
# 441      7         Sant Pere, Santa Caterina i la Ribera               17710
# 442      7                                 el Fort Pienc               21844
# ..     ...                                           ...                 ...
# 506      7  Diagonal Mar i el Front Marítim del Poblenou                8858
# 507      7                         el Besòs i el Maresme               16577
# 508      7                       Provençals del Poblenou               14217
# 509      7                      Sant Martí de Provençals               16219
# 510      7                           la Verneda i la Pau               17577
#
#      Unemployment_Rate
# ...

# %%
Agost = prova1[prova1.Month==8]

Agost
# Out:
#      Month                              Neighorbood_Name  Working_Population  \
# 511      8                                      el Raval               36405
# 512      8                                el Barri Gòtic               15462
# 513      8                                la Barceloneta               11337
# 514      8         Sant Pere, Santa Caterina i la Ribera               17710
# 515      8                                 el Fort Pienc               21844
# ..     ...                                           ...                 ...
# 579      8  Diagonal Mar i el Front Marítim del Poblenou                8858
# 580      8                         el Besòs i el Maresme               16577
# 581      8                       Provençals del Poblenou               14217
# 582      8                      Sant Martí de Provençals               16219
# 583      8                           la Verneda i la Pau               17577
#
#      Unemployment_Rate
# ...

# %%
Setembre = prova1[prova1.Month==9]

Setembre
# Out:
#      Month                              Neighorbood_Name  Working_Population  \
# 584      9                                      el Raval               36405
# 585      9                                el Barri Gòtic               15462
# 586      9                                la Barceloneta               11337
# 587      9         Sant Pere, Santa Caterina i la Ribera               17710
# 588      9                                 el Fort Pienc               21844
# ..     ...                                           ...                 ...
# 652      9  Diagonal Mar i el Front Marítim del Poblenou                8858
# 653      9                         el Besòs i el Maresme               16577
# 654      9                       Provençals del Poblenou               14217
# 655      9                      Sant Martí de Provençals               16219
# 656      9                           la Verneda i la Pau               17577
#
#      Unemployment_Rate
# ...

# %%
Octubre = prova1[prova1.Month==10]

Octubre
# Out:
#      Month                              Neighorbood_Name  Working_Population  \
# 657     10                                      el Raval               36405
# 658     10                                el Barri Gòtic               15462
# 659     10                                la Barceloneta               11337
# 660     10         Sant Pere, Santa Caterina i la Ribera               17710
# 661     10                                 el Fort Pienc               21844
# ..     ...                                           ...                 ...
# 725     10  Diagonal Mar i el Front Marítim del Poblenou                8858
# 726     10                         el Besòs i el Maresme               16577
# 727     10                       Provençals del Poblenou               14217
# 728     10                      Sant Martí de Provençals               16219
# 729     10                           la Verneda i la Pau               17577
#
#      Unemployment_Rate
# ...

# %%
Novembre = prova1[prova1.Month==11]

Novembre
# Out:
#      Month                              Neighorbood_Name  Working_Population  \
# 730     11                                      el Raval               36405
# 731     11                                el Barri Gòtic               15462
# 732     11                                la Barceloneta               11337
# 733     11         Sant Pere, Santa Caterina i la Ribera               17710
# 734     11                                 el Fort Pienc               21844
# ..     ...                                           ...                 ...
# 798     11  Diagonal Mar i el Front Marítim del Poblenou                8858
# 799     11                         el Besòs i el Maresme               16577
# 800     11                       Provençals del Poblenou               14217
# 801     11                      Sant Martí de Provençals               16219
# 802     11                           la Verneda i la Pau               17577
#
#      Unemployment_Rate
# ...

# %%
Novembre["Unemployment_Rate"].max()
# Out:
# 16.5

# %%
Inversio per creixement del valor del terra en cada barri si es vol mudar o invertir

comprar una casa









Indicant que hauria de fer una persona segons la estadística, dos opcions tirar amunt o avall


trobar feina, nivell atur, historia segons les estadistiques. tant per cent 






conspiracions, com la pujada del paro esta lligada a la creencia de les conspiracions, mes inteligencia menys creencia
conspiracions

# %%
prova4 = pd.read_csv("2020_Pes_del_atur_registrat_sobre_poblacio_16_64_anys_2.csv")

# %%
prova4
# Out:
#      Pes_atur                              Nom_Barri  Codi_Barri  \
# 0         8.4                               el Raval           1
# 1         5.9                         el Barri Gòtic           2
# 2         8.8                         la Barceloneta           3
# 3         7.8  Sant Pere, Santa Caterina i la Ribera           4
# 4         8.6                               el Raval           1
# ..        ...                                    ...         ...
# 798       3.8                                 Sarrià          23
# 799       4.6                        les Tres Torres          24
# 800       4.6             Sant Gervasi - la Bonanova          25
# 801       4.6                 Sant Gervasi - Galvany          26
# 802       6.5                   el Putxet i el Farró          27
#
#      Poblacio_16_64_anys  Mes
# 0                  36405    1
# 1                  15462    1
# 2                  11337    1
# 3                  17710    1
# ...

# %%
January.sort_values(by="Unemployment_Rate",ascending = False)
# Out:
#     Month                       Neighorbood_Name  Working_Population  \
# 54      1                       Ciutat Meridiana                7070
# 52      1                       la Trinitat Nova                5082
# 56      1                      la Trinitat Vella                6917
# 55      1                               Vallbona                 893
# 11      1             la Marina del Prat Vermell                 816
# ..    ...                                    ...                 ...
# 25      1                 Sant Gervasi - Galvany               29773
# 41      1                               la Clota                 479
# 21      1  Vallvidrera, el Tibidabo i les Planes                3121
# 22      1                                 Sarrià               14983
# 20      1                              Pedralbes                7025
#
#     Unemployment_Rate
# 54               13.0
# 52               12.5
# 56               12.3
# 55               11.9
# ...

# %%
Febrer.sort_values(by="Unemployment_Rate",ascending = False)
# Out:
#      Month                       Neighorbood_Name  Working_Population  \
# 127      2                       Ciutat Meridiana                7070
# 125      2                       la Trinitat Nova                5082
# 129      2                      la Trinitat Vella                6917
# 128      2                               Vallbona                 893
# 84       2             la Marina del Prat Vermell                 816
# ..     ...                                    ...                 ...
# 114      2                               la Clota                 479
# 98       2                 Sant Gervasi - Galvany               29773
# 95       2                                 Sarrià               14983
# 94       2  Vallvidrera, el Tibidabo i les Planes                3121
# 93       2                              Pedralbes                7025
#
#      Unemployment_Rate
# 127               13.0
# 125               12.5
# 129               12.3
# 128               12.0
# ...

# %%
Març.sort_values(by="Unemployment_Rate",ascending = False)
# Out:
#      Month                       Neighorbood_Name  Working_Population  \
# 200      3                       Ciutat Meridiana                7070
# 198      3                       la Trinitat Nova                5082
# 202      3                      la Trinitat Vella                6917
# 201      3                               Vallbona                 893
# 157      3             la Marina del Prat Vermell                 816
# ..     ...                                    ...                 ...
# 171      3                 Sant Gervasi - Galvany               29773
# 187      3                               la Clota                 479
# 168      3                                 Sarrià               14983
# 167      3  Vallvidrera, el Tibidabo i les Planes                3121
# 166      3                              Pedralbes                7025
#
#      Unemployment_Rate
# 200               13.6
# 198               13.1
# 202               12.8
# 201               12.5
# ...

# %%
Abril.sort_values(by="Unemployment_Rate",ascending = False)
# Out:
#      Month                       Neighorbood_Name  Working_Population  \
# 273      4                       Ciutat Meridiana                7070
# 271      4                       la Trinitat Nova                5082
# 275      4                      la Trinitat Vella                6917
# 230      4             la Marina del Prat Vermell                 816
# 274      4                               Vallbona                 893
# ..     ...                                    ...                 ...
# 244      4                 Sant Gervasi - Galvany               29773
# 260      4                               la Clota                 479
# 240      4  Vallvidrera, el Tibidabo i les Planes                3121
# 241      4                                 Sarrià               14983
# 239      4                              Pedralbes                7025
#
#      Unemployment_Rate
# 273               14.9
# 271               14.4
# 275               14.1
# 230               13.9
# ...

# %%
Maig.sort_values(by="Unemployment_Rate",ascending = False)
# Out:
#      Month                       Neighorbood_Name  Working_Population  \
# 346      5                       Ciutat Meridiana                7070
# 344      5                       la Trinitat Nova                5082
# 348      5                      la Trinitat Vella                6917
# 303      5             la Marina del Prat Vermell                 816
# 347      5                               Vallbona                 893
# ..     ...                                    ...                 ...
# 317      5                 Sant Gervasi - Galvany               29773
# 333      5                               la Clota                 479
# 313      5  Vallvidrera, el Tibidabo i les Planes                3121
# 314      5                                 Sarrià               14983
# 312      5                              Pedralbes                7025
#
#      Unemployment_Rate
# 346               15.8
# 344               15.2
# 348               14.9
# 303               14.8
# ...

# %%
Juny.sort_values(by="Unemployment_Rate",ascending = False)
# Out:
#      Month                       Neighorbood_Name  Working_Population  \
# 419      6                       Ciutat Meridiana                7070
# 417      6                       la Trinitat Nova                5082
# 421      6                      la Trinitat Vella                6917
# 376      6             la Marina del Prat Vermell                 816
# 420      6                               Vallbona                 893
# ..     ...                                    ...                 ...
# 390      6                 Sant Gervasi - Galvany               29773
# 406      6                               la Clota                 479
# 386      6  Vallvidrera, el Tibidabo i les Planes                3121
# 387      6                                 Sarrià               14983
# 385      6                              Pedralbes                7025
#
#      Unemployment_Rate
# 419               16.4
# 417               15.8
# 421               15.6
# 376               15.5
# ...

# %%
Juliol.sort_values(by="Unemployment_Rate",ascending = False)
# Out:
#      Month                       Neighorbood_Name  Working_Population  \
# 492      7                       Ciutat Meridiana                7070
# 490      7                       la Trinitat Nova                5082
# 494      7                      la Trinitat Vella                6917
# 449      7             la Marina del Prat Vermell                 816
# 493      7                               Vallbona                 893
# ..     ...                                    ...                 ...
# 463      7                 Sant Gervasi - Galvany               29773
# 479      7                               la Clota                 479
# 459      7  Vallvidrera, el Tibidabo i les Planes                3121
# 460      7                                 Sarrià               14983
# 458      7                              Pedralbes                7025
#
#      Unemployment_Rate
# 492               16.0
# 490               15.4
# 494               15.2
# 449               15.2
# ...

# %%
Agost.sort_values(by="Unemployment_Rate",ascending = False)
# Out:
#      Month                       Neighorbood_Name  Working_Population  \
# 565      8                       Ciutat Meridiana                7070
# 563      8                       la Trinitat Nova                5082
# 567      8                      la Trinitat Vella                6917
# 566      8                               Vallbona                 893
# 522      8             la Marina del Prat Vermell                 816
# ..     ...                                    ...                 ...
# 536      8                 Sant Gervasi - Galvany               29773
# 552      8                               la Clota                 479
# 533      8                                 Sarrià               14983
# 532      8  Vallvidrera, el Tibidabo i les Planes                3121
# 531      8                              Pedralbes                7025
#
#      Unemployment_Rate
# 565               16.4
# 563               15.8
# 567               15.6
# 566               15.1
# ...

# %%
Setembre.sort_values(by="Unemployment_Rate",ascending = False)
# Out:
#      Month                       Neighorbood_Name  Working_Population  \
# 638      9                       Ciutat Meridiana                7070
# 636      9                       la Trinitat Nova                5082
# 640      9                      la Trinitat Vella                6917
# 639      9                               Vallbona                 893
# 595      9             la Marina del Prat Vermell                 816
# ..     ...                                    ...                 ...
# 609      9                 Sant Gervasi - Galvany               29773
# 625      9                               la Clota                 479
# 606      9                                 Sarrià               14983
# 605      9  Vallvidrera, el Tibidabo i les Planes                3121
# 604      9                              Pedralbes                7025
#
#      Unemployment_Rate
# 638               16.1
# 636               15.5
# 640               15.3
# 639               14.8
# ...

# %%
Octubre.sort_values(by="Unemployment_Rate",ascending = False)
# Out:
#      Month                       Neighorbood_Name  Working_Population  \
# 711     10                       Ciutat Meridiana                7070
# 709     10                       la Trinitat Nova                5082
# 713     10                      la Trinitat Vella                6917
# 668     10             la Marina del Prat Vermell                 816
# 712     10                               Vallbona                 893
# ..     ...                                    ...                 ...
# 681     10             Sant Gervasi - la Bonanova               15861
# 698     10                               la Clota                 479
# 679     10                                 Sarrià               14983
# 678     10  Vallvidrera, el Tibidabo i les Planes                3121
# 677     10                              Pedralbes                7025
#
#      Unemployment_Rate
# 711               16.6
# 709               16.0
# 713               15.7
# 668               15.7
# ...

# %%
Novembre.sort_values(by="Unemployment_Rate",ascending = False)
# Out:
#      Month                       Neighorbood_Name  Working_Population  \
# 784     11                       Ciutat Meridiana                7070
# 782     11                       la Trinitat Nova                5082
# 786     11                      la Trinitat Vella                6917
# 741     11             la Marina del Prat Vermell                 816
# 785     11                               Vallbona                 893
# ..     ...                                    ...                 ...
# 754     11             Sant Gervasi - la Bonanova               15861
# 771     11                               la Clota                 479
# 752     11                                 Sarrià               14983
# 751     11  Vallvidrera, el Tibidabo i les Planes                3121
# 750     11                              Pedralbes                7025
#
#      Unemployment_Rate
# 784               16.5
# 782               15.9
# 786               15.6
# 741               15.5
# ...
