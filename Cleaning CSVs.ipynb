# %%
import pandas as pd
import numpy as np
import os

# %%
csv_holidays = pd.read_csv("datasets/1.-Transportation/accidents-holidays.csv")
csv_holidays
# Out:
#      Unnamed: 0        District Name  Weekday     Month  Day Part of the day  \
# 0             0         Ciutat Vella   Friday      June   23           Night
# 1             1             Eixample   Friday      June   23         Morning
# 2             2             Eixample   Friday      June   23         Morning
# 3             3             Eixample   Friday      June   23       Afternoon
# 4             4       Sants-Montjuïc   Friday      June   23       Afternoon
# ..          ...                  ...      ...       ...  ...             ...
# 683         683             Eixample  Tuesday  February   14         Morning
# 684         684            Les Corts  Tuesday  February   14         Morning
# 685         685  Sarrià-Sant Gervasi  Tuesday  February   14       Afternoon
# 686         686       Horta-Guinardó  Tuesday  February   14       Afternoon
# 687         687       Horta-Guinardó  Tuesday  February   14         Morning
#
# ...

# %%
csv_holidays.drop(["Unnamed: 0"], axis=1, inplace=True)
csv_holidays
# Out:
#            District Name  Weekday     Month  Day Part of the day  \
# 0           Ciutat Vella   Friday      June   23           Night
# 1               Eixample   Friday      June   23         Morning
# 2               Eixample   Friday      June   23         Morning
# 3               Eixample   Friday      June   23       Afternoon
# 4         Sants-Montjuïc   Friday      June   23       Afternoon
# ..                   ...      ...       ...  ...             ...
# 683             Eixample  Tuesday  February   14         Morning
# 684            Les Corts  Tuesday  February   14         Morning
# 685  Sarrià-Sant Gervasi  Tuesday  February   14       Afternoon
# 686       Horta-Guinardó  Tuesday  February   14       Afternoon
# 687       Horta-Guinardó  Tuesday  February   14         Morning
#
#      Mild injuries  Serious injuries  Victims  Vehicles involved
# 0                1                 0        1                  1
# ...

# %%
csv_without_holidays = pd.read_csv("datasets/1.-Transportation/accidents-without-holidays.csv")
csv_without_holidays
# Out:
#       Unnamed: 0 District Name    Weekday      Month  Day Part of the day  \
# 0              0       Unknown     Friday    October   13         Morning
# 1              1       Unknown     Friday  September    1         Morning
# 2              3       Unknown     Friday       July   21           Night
# 3              4    Sant Martí   Thursday        May   25       Afternoon
# 4              5    Sant Martí  Wednesday  September   20         Morning
# ...          ...           ...        ...        ...  ...             ...
# 9646       10334   Sant Andreu    Tuesday      April   25         Morning
# 9647       10335   Sant Andreu  Wednesday      March    8         Morning
# 9648       10336   Sant Andreu   Thursday   December   28         Morning
# 9649       10337   Sant Andreu     Friday       July   14       Afternoon
# 9650       10338   Sant Andreu     Sunday    January    8       Afternoon
#
#       Mild injuries  Serious injuries  Victims  Vehicles involved
# ...

# %%
csv_without_holidays.drop(["Unnamed: 0"], axis=1, inplace=True)
csv_without_holidays
# Out:
#      District Name    Weekday      Month  Day Part of the day  Mild injuries  \
# 0          Unknown     Friday    October   13         Morning              2
# 1          Unknown     Friday  September    1         Morning              2
# 2          Unknown     Friday       July   21           Night              1
# 3       Sant Martí   Thursday        May   25       Afternoon              1
# 4       Sant Martí  Wednesday  September   20         Morning              1
# ...            ...        ...        ...  ...             ...            ...
# 9646   Sant Andreu    Tuesday      April   25         Morning              1
# 9647   Sant Andreu  Wednesday      March    8         Morning              1
# 9648   Sant Andreu   Thursday   December   28         Morning              1
# 9649   Sant Andreu     Friday       July   14       Afternoon              1
# 9650   Sant Andreu     Sunday    January    8       Afternoon              0
#
# ...

# %%
original_file = pd.read_csv("datasets/1.-Transportation/accidents-2017.csv")
original_file
# Out:
#                     Id District Name           Neighborhood Name  \
# 0      2017S008429           Unknown                     Unknown
# 1      2017S007316           Unknown                     Unknown
# 2      2017S010210           Unknown                     Unknown
# 3      2017S006364           Unknown                     Unknown
# 4      2017S004615        Sant Martí  el Camp de l'Arpa del Clot
# ...                ...           ...                         ...
# 10334  2017S003667       Sant Andreu               el Bon Pastor
# 10335  2017S001896       Sant Andreu               el Bon Pastor
# 10336  2017S010718       Sant Andreu               el Bon Pastor
# 10337  2017S006145       Sant Andreu               el Bon Pastor
# 10338  2017S000178       Sant Andreu               el Bon Pastor
#
#                                                   Street    Weekday  \
# 0      Número 27                                     ...     Friday
# ...
