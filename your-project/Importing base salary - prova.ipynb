# %% [markdown]
# ## Importing base salary pero ho faig aqui per si de cas

# %%
import pandas as pd
import numpy as np
from functools import reduce

# %%
salary = pd.read_csv("../datasets/Data_filtered/average_wages_world.csv")

# %%
salary.loc[salary["TIME"]==2018]
# Out:
#     LOCATION INDICATOR SUBJECT MEASURE FREQUENCY  TIME         Value  \
# 28       AUS    AVWAGE     TOT     USD         A  2018  53349.413615
# 57       AUT    AVWAGE     TOT     USD         A  2018  50868.246007
# 86       BEL    AVWAGE     TOT     USD         A  2018  52079.615311
# 115      CAN    AVWAGE     TOT     USD         A  2018  48848.522502
# 139      CZE    AVWAGE     TOT     USD         A  2018  26961.575591
# 168      DNK    AVWAGE     TOT     USD         A  2018  55253.342027
# 197      FIN    AVWAGE     TOT     USD         A  2018  44111.400030
# 226      FRA    AVWAGE     TOT     USD         A  2018  44510.133176
# 254      DEU    AVWAGE     TOT     USD         A  2018  49813.200120
# 278      GRC    AVWAGE     TOT     USD         A  2018  26670.954267
# 302      HUN    AVWAGE     TOT     USD         A  2018  24454.710794
# 331      IRL    AVWAGE     TOT     USD         A  2018  47951.852433
# 360      ITA    AVWAGE     TOT     USD         A  2018  37751.934636
# ...
