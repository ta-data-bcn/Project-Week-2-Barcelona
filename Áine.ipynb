# %%
import pandas as pd
import numpy as np
import re

# %%
total = pd.read_csv("datasets/1.-Transportation/accidents-2017.csv")

# %%
total.head()
# Out:
#                 Id District Name           Neighborhood Name  \
# 0  2017S008429           Unknown                     Unknown
# 1  2017S007316           Unknown                     Unknown
# 2  2017S010210           Unknown                     Unknown
# 3  2017S006364           Unknown                     Unknown
# 4  2017S004615        Sant Martí  el Camp de l'Arpa del Clot
#
#                                               Street   Weekday      Month  \
# 0  Número 27                                     ...    Friday    October
# 1  Número 3 Zona Franca / Número 50 Zona Franca  ...    Friday  September
# 2  Litoral (Besòs)                               ...    Friday   December
# 3  Número 3 Zona Franca                          ...    Friday       July
# 4  Las Navas de Tolosa                           ...  Thursday        May
#
#    Day  Hour Part of the day  Mild injuries  Serious injuries  Victims  \
# 0   13     8         Morning              2                 0        2
# ...

# %%
holiday_acc = pd.read_csv("datasets/1.-Transportation/accidents-holidays.csv")

# %%
holiday_acc['Day'] = holiday_acc.Day.astype(str)

# %%
holiday_acc["Date"] = holiday_acc["Month"] + " " + holiday_acc["Day"]

# %%
holiday_acc.to_csv("datasets/1.-Transportation/new_holiday.csv")

# %%
serious_hol = holiday_acc.sort_values("Serious injuries", ascending=False)

# %%
serious_hol.head(30)
# Out:
#      Unnamed: 0        District Name   Weekday      Month  Day  \
# 562         562            Les Corts    Sunday       June    4
# 641         641           Sant Martí    Sunday      April   23
# 362         362  Sarrià-Sant Gervasi  Saturday    January    7
# 567         567           Nou Barris    Friday       June    2
# 227         227             Eixample    Friday      April   14
# 380         380             Eixample  Saturday    January    7
# 202         202             Eixample    Sunday      April   16
# 375         375            Les Corts  Saturday    January    7
# 457         457             Eixample  Saturday      April   29
# 372         372             Eixample  Saturday    January    7
# 110         110             Eixample    Friday  September   22
# 271         271            Les Corts    Monday  September   11
# 512         512             Eixample    Sunday       June    4
# 520         520           Nou Barris    Monday       June    5
# ...

# %%
holiday_acc["Serious injuries"].sum()
# Out:
# 20

# %%
no_hol = pd.read_csv("datasets/1.-Transportation/accidents-without-holidays.csv")

# %%
no_hol["Serious injuries"].sum()
# Out:
# 221

# %%
no_hol['Day'] = no_hol.Day.astype(str)

# %%
no_hol["Date"] = no_hol["Month"] + " " + no_hol["Day"]

# %%
no_hol.head()
# Out:
#    Unnamed: 0 District Name    Weekday      Month Day Part of the day  \
# 0           0       Unknown     Friday    October  13         Morning
# 1           1       Unknown     Friday  September   1         Morning
# 2           3       Unknown     Friday       July  21           Night
# 3           4    Sant Martí   Thursday        May  25       Afternoon
# 4           5    Sant Martí  Wednesday  September  20         Morning
#
#    Mild injuries  Serious injuries  Victims  Vehicles involved          Date
# 0              2                 0        2                  2    October 13
# 1              2                 0        2                  2   September 1
# 2              1                 0        1                  2       July 21
# 3              1                 0        1                  3        May 25
# 4              1                 0        1                  2  September 20

# %%
new_no_hol = no_hol.to_csv("datasets/1.-Transportation/new_no_hol.csv")
