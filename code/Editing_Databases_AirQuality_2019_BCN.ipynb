# %% [markdown]
# ### Importing CSVs.

# %%
import pandas as pd

# %%
#Reading Csvs
jan = pd.read_csv("../datasets/2.-Urban-Environment/2019_01_Gener_qualitat_aire_BCN.csv", names = ["Station_Name","Air_Quality","Code_dtes","ZQA","Code_eoi","Lenght","Latitude","Time_03","Quality_03","Value_O3","Time_NO2","Quality_NO2","Value_NO2","Time_PM10","Quality_PM10","Value_PM10","DayTaken","DateTime"])
feb = pd.read_csv("../datasets/2.-Urban-Environment/2019_02_Febrer_qualitat_aire_BCN.csv",names = ["Station_Name","Air_Quality","Code_dtes","ZQA","Code_eoi","Lenght","Latitude","Time_03","Quality_03","Value_O3","Time_NO2","Quality_NO2","Value_NO2","Time_PM10","Quality_PM10","Value_PM10","DayTaken","DateTime"])
mar = pd.read_csv("../datasets/2.-Urban-Environment/2019_03_Marc_qualitat_aire_BCN.csv",names = ["Station_Name","Air_Quality","Code_dtes","ZQA","Code_eoi","Lenght","Latitude","Time_03","Quality_03","Value_O3","Time_NO2","Quality_NO2","Value_NO2","Time_PM10","Quality_PM10","Value_PM10","DayTaken","DateTime"])
apr = pd.read_csv("../datasets/2.-Urban-Environment/2019_04_Abril_qualitat_aire_BCN.csv",names = ["Station_Name","Air_Quality","Code_dtes","ZQA","Code_eoi","Lenght","Latitude","Time_03","Quality_03","Value_O3","Time_NO2","Quality_NO2","Value_NO2","Time_PM10","Quality_PM10","Value_PM10","DayTaken","DateTime"])
may = pd.read_csv("../datasets/2.-Urban-Environment/2019_05_Maig_qualitat_aire_BCN.csv",names = ["Station_Name","Air_Quality","Code_dtes","ZQA","Code_eoi","Lenght","Latitude","Time_03","Quality_03","Value_O3","Time_NO2","Quality_NO2","Value_NO2","Time_PM10","Quality_PM10","Value_PM10","DayTaken","DateTime"])
jun = pd.read_csv("../datasets/2.-Urban-Environment/2019_06_Juny_qualitat_aire_BCN.csv",names = ["Station_Name","Air_Quality","Code_dtes","ZQA","Code_eoi","Lenght","Latitude","Time_03","Quality_03","Value_O3","Time_NO2","Quality_NO2","Value_NO2","Time_PM10","Quality_PM10","Value_PM10","DayTaken","DateTime"])
jul = pd.read_csv("../datasets/2.-Urban-Environment/2019_07_Juliol_qualitat_aire_BCN.csv",names = ["Station_Name","Air_Quality","Code_dtes","ZQA","Code_eoi","Lenght","Latitude","Time_03","Quality_03","Value_O3","Time_NO2","Quality_NO2","Value_NO2","Time_PM10","Quality_PM10","Value_PM10","DayTaken","DateTime"])
aug = pd.read_csv("../datasets/2.-Urban-Environment/2019_08_Agost_qualitat_aire_BCN.csv",names = ["Station_Name","Air_Quality","Code_dtes","ZQA","Code_eoi","Lenght","Latitude","Time_03","Quality_03","Value_O3","Time_NO2","Quality_NO2","Value_NO2","Time_PM10","Quality_PM10","Value_PM10","DayTaken","DateTime"])
sep = pd.read_csv("../datasets/2.-Urban-Environment/2019_09_Setembre_qualitat_aire_BCN.csv",names = ["Station_Name","Air_Quality","Code_dtes","ZQA","Code_eoi","Lenght","Latitude","Time_03","Quality_03","Value_O3","Time_NO2","Quality_NO2","Value_NO2","Time_PM10","Quality_PM10","Value_PM10","DayTaken","DateTime"])
octo = pd.read_csv("../datasets/2.-Urban-Environment/2019_10_Octubre_qualitat_aire_BCN.csv",names = ["Station_Name","Air_Quality","Code_dtes","ZQA","Code_eoi","Lenght","Latitude","Time_03","Quality_03","Value_O3","Time_NO2","Quality_NO2","Value_NO2","Time_PM10","Quality_PM10","Value_PM10","DayTaken","DateTime"])
nov = pd.read_csv("../datasets/2.-Urban-Environment/2019_11_Novembre_qualitat_aire_BCN.csv",names = ["Station_Name","Air_Quality","Code_dtes","ZQA","Code_eoi","Lenght","Latitude","Time_03","Quality_03","Value_O3","Time_NO2","Quality_NO2","Value_NO2","Time_PM10","Quality_PM10","Value_PM10","DayTaken","DateTime"])
dec = pd.read_csv("../datasets/2.-Urban-Environment/2019_12_Desembre_qualitat_aire_BCN.csv",names = ["Station_Name","Air_Quality","Code_dtes","ZQA","Code_eoi","Lenght","Latitude","Time_03","Quality_03","Value_O3","Time_NO2","Quality_NO2","Value_NO2","Time_PM10","Quality_PM10","Value_PM10","DayTaken","DateTime"])

# %%
# Out:
#                                         Station_Name  Air_Quality  Code_dtes  \
# 0  CODI_PROVINCIA;PROVINCIA;CODI_MUNICIPI;MUNICIP...          NaN        NaN
# 1  08;Barcelona;019;Barcelona;4;7;2019;6;1;7;V;15...          NaN        NaN
# 2  08;Barcelona;019;Barcelona;4;7;2019;6;2;1;V;2;...          NaN        NaN
# 3  08;Barcelona;019;Barcelona;4;7;2019;6;3;2;V;9;...          NaN        NaN
# 4  08;Barcelona;019;Barcelona;4;7;2019;6;4;2;V;2;...          NaN        NaN
#
#    ZQA  Code_eoi  Lenght  Latitude  Time_03  Quality_03  Value_O3  Time_NO2  \
# 0  NaN       NaN     NaN       NaN      NaN         NaN       NaN       NaN
# 1  NaN       NaN     NaN       NaN      NaN         NaN       NaN       NaN
# 2  NaN       NaN     NaN       NaN      NaN         NaN       NaN       NaN
# 3  NaN       NaN     NaN       NaN      NaN         NaN       NaN       NaN
# 4  NaN       NaN     NaN       NaN      NaN         NaN       NaN       NaN
#
# ...

# %%
#Putting all the Data Frames together

# %%
airq_2019 = pd.concat([jan,feb,mar,apr,may,jun,jul,aug], axis=0, copy=True)

# %%
airq_2019.head()
# Out:
#                 nom_cabina qualitat_aire codi_dtes  zqa   codi_eoi  longitud  \
# 0        Barcelona - Sants          Bona        ID  1.0  8019042.0    2.1331
# 1     Barcelona - Eixample       Regular        IH  1.0  8019043.0    2.1538
# 2       Barcelona - Gràcia       Regular        IJ  1.0  8019044.0    2.1534
# 3   Barcelona - Ciutadella          Bona        IL  1.0  8019050.0    2.1874
# 4  Barcelona - Vall Hebron          Bona        IN  1.0  8019054.0    2.1480
#
#    latitud hora_o3 qualitat_o3  valor_o3  ...  V20 H21  V21 H22  V22 H23  V23  \
# 0  41.3788     NaN         NaN       NaN  ...  NaN NaN  NaN NaN  NaN NaN  NaN
# 1  41.3853     23h        Bona   3 µg/m³  ...  NaN NaN  NaN NaN  NaN NaN  NaN
# 2  41.3987     23h        Bona   3 µg/m³  ...  NaN NaN  NaN NaN  NaN NaN  NaN
# 3  41.3864     23h        Bona   2 µg/m³  ...  NaN NaN  NaN NaN  NaN NaN  NaN
# 4  41.4261     23h        Bona  10 µg/m³  ...  NaN NaN  NaN NaN  NaN NaN  NaN
#
#    H24  V24  \
# 0  NaN  NaN
# ...
