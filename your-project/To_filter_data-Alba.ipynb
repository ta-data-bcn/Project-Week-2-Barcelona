# %% [markdown]
# # Data filtering

# %%
import pandas as pd
import numpy as np

# %%
#import the datasets from which we need to obtain the info and summarize

children=pd.read_csv("../datasets/unfiltered/Children_spaces_bcn.csv")

cinema=pd.read_csv("../datasets/unfiltered/Cinemas_and_theatres_bcn.csv")

education=pd.read_csv("../datasets/unfiltered/Education_centers_children_bcn.csv")

educationkids=pd.read_csv("../datasets/unfiltered/Educative_centers_bcn.csv")

hospital=pd.read_csv("../datasets/unfiltered/Hospitals_bcn.csv")

library=pd.read_csv("../datasets/unfiltered/Library_and_museums_bcn.csv")

bars=pd.read_csv("../datasets/unfiltered/Music_and_drinks_venues_bcn.csv")

park=pd.read_csv("../datasets/unfiltered/Parks_and_gardens_bcn.csv")

sport=pd.read_csv("../datasets/unfiltered/Sport_facilities_centers.csv")

# %%
#Quick look it they uploaded ok

children.head()
hospital.tail()

#all good and with no index
# Out:
#      CODI_EQUIPAMENT                             EQUIPAMENT  \
# 394      99400593384                         Hospital Plató
# 395      99400593385  Hospital  Universitari del Sagrat Cor
# 396      99400607886            Clínica Podològica Integral
# 397      99400632531        Centre d'Atenció Primària Roger
# 398      99400632531        Centre d'Atenció Primària Roger
#
#                                     SECCIO TIPUS_VIA   NOM_CARRER  \
# 394  Centre d'Urgències d'Atenció Primària         C        Plató
# 395  Centre d'Urgències d'Atenció Primària         C    Viladomat
# 396                                      #        Pg  Zona Franca
# 397                                      #         C        Roger
# 398                                      #         C        Roger
#
#      NUM_CARRER_1  NUM_CARRER_2  CODI_BARRI                       NUM_BARRI  \
# 394            21          21.0          26          Sant Gervasi - Galvany
# 395           288         288.0           9  la Nova Esquerra de l'Eixample
# 396           242         242.0          13               la Marina de Port
# 397            48          64.0          17                   Sants - Badal
# 398            48          64.0          17                   Sants - Badal
#
#      CODI_DISTRICTE  ... TELEFON_NUM  TELEFON_TIPUS        TELEFON_INFO_COM  \
# 394               5  ...   933069900     Centraleta                     NaN
# 395               2  ...   933221111     Centraleta                     NaN
# 396               3  ...   606142924           Tel.                     NaN
# 397               3  ...   933268901           Tel.  Programació de visites
# 398               3  ...   934310039     Centraleta                     NaN
#
#     HORARI_PERIODE_INICI  HORARI_PERIODE_FI  HORARI_DIES  HORARI_HORES_INICI  \
# 394                01/01              31/12          0.0            00:00:00
# 395                01/01              31/12          0.0            00:00:00
# 396                  NaN                NaN          NaN                 NaN
# 397                01/01              31/12         11.0            08:00:00
# 398                01/01              31/12         11.0            08:00:00
#
#      HORARI_HORES_FI                                HORARI_OBSERVACIONS  \
# 394         23:59:00
# 395         23:59:00
# 396              NaN                                                NaN
# 397         20:00:00  Fora d'aquest horari truqueu al 061<br>o CUAP ...
# 398         20:00:00  Fora d'aquest horari truqueu al 061<br>o CUAP ...
#
#      Unnamed: 29
# 394          NaN
# 395          NaN
# 396          NaN
# 397          NaN
# 398          NaN
#
# [5 rows x 30 columns]

# %%
#necessary to obtain the times that each neighbourhood appears (variable "NUM_BARRI")
#and save it

# %%
#to get a frequency table

COUNT=hospital.groupby("NUM_BARRI").size()

# %%
COUNT
# Out:
# NUM_BARRI
# Diagonal Mar i el Front Marítim del Poblenou     3
# Horta                                            6
# Montbau                                         13
# Provençals del Poblenou                          1
# Sant Andreu                                     13
# Sant Antoni                                      6
# Sant Gervasi - Galvany                          22
# Sant Gervasi - la Bonanova                      12
# Sant Martí de Provençals                         4
# Sant Pere, Santa Caterina i la Ribera            6
# Sants                                           14
# Sants - Badal                                    2
# Sarrià                                          15
# Torre Baró                                       6
# Vallcarca i els Penitents                       14
# Vallvidrera, el Tibidabo i les Planes            2
# Verdun                                           2
# Vilapicina i la Torre Llobeta                    5
# el Baix Guinardó                                 4
# el Barri Gòtic                                   3
# el Besòs i el Maresme                            8
# el Bon Pastor                                    3
# el Camp d'en Grassot i Gràcia Nova               5
# el Camp de l'Arpa del Clot                       9
# el Carmel                                       10
# el Clot                                          5
# el Fort Pienc                                    7
# el Guinardó                                     11
# el Poble-sec                                     4
# el Poblenou                                      6
# el Putxet i el Farró                             4
# el Raval                                        12
# el Turó de la Peira                              4
# l'Antiga Esquerra de l'Eixample                 12
# la Barceloneta                                  13
# la Bordeta                                       3
# la Dreta de Eixample                             7
# la Guineueta                                     6
# la Marina de Port                               13
# la Maternitat i Sant Ramon                      10
# la Nova Esquerra de l'Eixample                   7
# la Prosperitat                                   6
# la Sagrada Família                               9
# la Sagrera                                       4
# la Salut                                        19
# la Trinitat Nova                                 4
# la Trinitat Vella                                4
# la Verneda i la Pau                              3
# la Vila Olímpica del Poblenou                    4
# la Vila de Gràcia                                6
# les Corts                                        9
# les Roquetes                                     6
# les Tres Torres                                 13
# dtype: int64

# %%
COUNT.to_csv("Count.csv")

# %%
count=pd.read_csv("Count.csv")
count
# Out:
#                         NUM_BARRI   0
# 0                   Baró de Viver   8
# 1                        Can Baró   6
# 2                     Can Peguera   4
# 3                       Canyelles   4
# 4                Ciutat Meridiana  14
# ..                            ...  ..
# 67  la Vila Olímpica del Poblenou   8
# 68              la Vila de Gràcia  20
# 69                      les Corts  24
# 70                   les Roquetes  12
# 71                les Tres Torres  10
#
# [72 rows x 2 columns]

# %%
count2=count.rename(columns={"NUM_BARRI":"Nbh","0":"Children_places"})

# %%
count2.columns
# Out:
# Index(['Nbh', 'Children_places'], dtype='object')

# %%
count2.to_csv("../datasets/Data_filtered/Children_places.csv")

# %% [markdown]
# ## Now we do the same with all the data sets

# %%
#we already imported them before
cinema
education
educationkids
hospital
library  #there are empty values here 
bars
park #empty values here too
sport

# %%
#checking if the value exists for all of them, it does
#sport["NUM_BARRI"]

# %%
#step2: frequency table

cinema=cinema.groupby("NUM_BARRI").size()

education=education.groupby("NUM_BARRI").size()

educationkids=educationkids.groupby("NUM_BARRI").size()

hospital=hospital.groupby("NUM_BARRI").size()

library=library.groupby("NUM_BARRI").size()

bars=bars.groupby("NUM_BARRI").size()

park=park.groupby("NUM_BARRI").size()

sport=sport.groupby("NUM_BARRI").size()

# %%
education
# Out:
# NUM_BARRI
# Baró de Viver                                    5
# Can Baró                                         4
# Canyelles                                        3
# Ciutat Meridiana                                 7
# Diagonal Mar i el Front Marítim del Poblenou     7
#                                                 ..
# la Vila Olímpica del Poblenou                    8
# la Vila de Gràcia                               35
# les Corts                                       35
# les Roquetes                                     7
# les Tres Torres                                  3
# Length: 71, dtype: int64

# %%
#step3: saving the files as .csv

cinema.to_csv("../datasets/Data_filtered/cinema.csv")

education.to_csv("../datasets/Data_filtered/education.csv")

educationkids.to_csv("../datasets/Data_filtered/educationkids.csv")

hospital.to_csv("../datasets/Data_filtered/hospital.csv")

library.to_csv("../datasets/Data_filtered/library.csv")

bars.to_csv("../datasets/Data_filtered/bars.csv")

park.to_csv("../datasets/Data_filtered/park.csv")

sport.to_csv("../datasets/Data_filtered/sport.csv")

# %%
#importing them again

cinema=pd.read_csv("../datasets/Data_filtered/cinema.csv")

education=pd.read_csv("../datasets/Data_filtered/education.csv")

educationkids=pd.read_csv("../datasets/Data_filtered/educationkids.csv")

hospital=pd.read_csv("../datasets/Data_filtered/hospital.csv")

library=pd.read_csv("../datasets/Data_filtered/library.csv")

bars=pd.read_csv("../datasets/Data_filtered/bars.csv")

park=pd.read_csv("../datasets/Data_filtered/park.csv")

sport=pd.read_csv("../datasets/Data_filtered/sport.csv")

# %%
#renaming the columns

cinema=cinema.rename(columns={"NUM_BARRI":"Nbh","0":"Cinemas_Theatres"})

education=count.rename(columns={"NUM_BARRI":"Nbh","0":"Schools"})

educationkids=count.rename(columns={"NUM_BARRI":"Nbh","0":"Pre-Schools"})

hospital=count.rename(columns={"NUM_BARRI":"Nbh","0":"Hospitals"})

library=count.rename(columns={"NUM_BARRI":"Nbh","0":"Libraries_Theatres"})

bars=count.rename(columns={"NUM_BARRI":"Nbh","0":"Bars"})

park=count.rename(columns={"NUM_BARRI":"Nbh","0":"Park_Gardens"})

sport=count.rename(columns={"NUM_BARRI":"Nbh","0":"Sport_Centers"})

# %%
#saving the files again

cinema.to_csv("../datasets/Data_filtered/cinema.csv")

education.to_csv("../datasets/Data_filtered/education.csv")

educationkids.to_csv("../datasets/Data_filtered/educationkids.csv")

hospital.to_csv("../datasets/Data_filtered/hospital.csv")

library.to_csv("../datasets/Data_filtered/library.csv")

bars.to_csv("../datasets/Data_filtered/bars.csv")

park.to_csv("../datasets/Data_filtered/park.csv")

sport.to_csv("../datasets/Data_filtered/sport.csv")

# %%
#Let's filter what's left

population=pd.read_csv("../datasets/unfiltered/2017_densitat.csv")

rental=pd.read_csv("../datasets/unfiltered/2017_lloguer_preu_trim.csv")

tenants=pd.read_csv("../datasets/unfiltered/2017_ocupacio_mitjana_domicilis.csv")

# %%
#we want to keep:
#population (Població) and Densitat neta which is the number of habitans per habitable hectares(ha) residental surface
population.head()
# Out:
#     Any  Codi_Districte Nom_Districte  Codi_Barri  \
# 0  2017               1  Ciutat Vella           1
# 1  2017               1  Ciutat Vella           2
# 2  2017               1  Ciutat Vella           3
# 3  2017               1  Ciutat Vella           4
# 4  2017               2      Eixample           5
#
#                                Nom_Barri  Població  Superfície (ha)  \
# 0                               el Raval     47608            109.8
# 1                         el Barri Gòtic     16062             84.2
# 2                         la Barceloneta     14996            131.4
# 3  Sant Pere, Santa Caterina i la Ribera     22721            111.4
# 4                          el Fort Pienc     32016             92.9
#
#    Superfície Residencial (ha)  Densitat (hab/ha)  Densitat neta (hab/ha)
# 0                         49.7                433                     959
# 1                         34.1                191                     471
# 2                         13.5                114                    1107
# 3                         32.5                204                     700
# 4                         33.4                345                     959

# %%
#select what I want

population= population[["Nom_Barri","Població","Densitat neta (hab/ha)"]]

population
# Out:
#                                        Nom_Barri  Població  \
# 0                                       el Raval     47608
# 1                                 el Barri Gòtic     16062
# 2                                 la Barceloneta     14996
# 3          Sant Pere, Santa Caterina i la Ribera     22721
# 4                                  el Fort Pienc     32016
# ..                                           ...       ...
# 68  Diagonal Mar i el Front Marítim del Poblenou     13629
# 69                         el Besòs i el Maresme     23009
# 70                       Provençals del Poblenou     20487
# 71                      Sant Martí de Provençals     26146
# 72                           la Verneda i la Pau     28691
#
#     Densitat neta (hab/ha)
# 0                      959
# 1                      471
# 2                     1107
# 3                      700
# 4                      959
# ..                     ...
# 68                     592
# 69                     885
# 70                    1490
# 71                    1116
# 72                     716
#
# [73 rows x 3 columns]

# %%
#rename
population.rename(columns={"Nom_Barri":"Nbh","Població":"Population","Densitat neta (hab/ha)":"Net_density(hab/ha)"})
# Out:
#                                              Nbh  Population  \
# 0                                       el Raval       47608
# 1                                 el Barri Gòtic       16062
# 2                                 la Barceloneta       14996
# 3          Sant Pere, Santa Caterina i la Ribera       22721
# 4                                  el Fort Pienc       32016
# ..                                           ...         ...
# 68  Diagonal Mar i el Front Marítim del Poblenou       13629
# 69                         el Besòs i el Maresme       23009
# 70                       Provençals del Poblenou       20487
# 71                      Sant Martí de Provençals       26146
# 72                           la Verneda i la Pau       28691
#
#     Net_density(hab/ha)
# 0                   959
# 1                   471
# 2                  1107
# 3                   700
# 4                   959
# ..                  ...
# 68                  592
# 69                  885
# 70                 1490
# 71                 1116
# 72                  716
#
# [73 rows x 3 columns]

# %%
#safe the file
population.to_csv("../datasets/Data_filtered/population.csv")

# %%
rental.head()  #Nom_Barri,Preu
# Out:
#     Any  Trimestre  Codi_Districte Nom_Districte  Codi_Barri  \
# 0  2017          1               1  Ciutat Vella           1
# 1  2017          1               1  Ciutat Vella           2
# 2  2017          1               1  Ciutat Vella           3
# 3  2017          1               1  Ciutat Vella           4
# 4  2017          1               2      Eixample           5
#
#                                Nom_Barri                      Lloguer_mitja  \
# 0                               el Raval  Lloguer mitjà mensual (Euros/mes)
# 1                         el Barri Gòtic  Lloguer mitjà mensual (Euros/mes)
# 2                         la Barceloneta  Lloguer mitjà mensual (Euros/mes)
# 3  Sant Pere, Santa Caterina i la Ribera  Lloguer mitjà mensual (Euros/mes)
# 4                          el Fort Pienc  Lloguer mitjà mensual (Euros/mes)
#
#      Preu
# 0  734.99
# 1  905.26
# 2  722.78
# 3  895.28
# 4  871.08

# %%
rental= rental[["Nom_Barri","Preu"]]

# %%
rental.rename(columns={"Nom_Barri":"Nbh","Preu":"Rental_price(€)/month"})
# Out:
#                                               Nbh  Rental_price(€)/month
# 0                                        el Raval                 734.99
# 1                                  el Barri Gòtic                 905.26
# 2                                  la Barceloneta                 722.78
# 3           Sant Pere, Santa Caterina i la Ribera                 895.28
# 4                                   el Fort Pienc                 871.08
# ..                                            ...                    ...
# 579  Diagonal Mar i el Front Marítim del Poblenou                  16.51
# 580                         el Besòs i el Maresme                  10.40
# 581                       Provençals del Poblenou                  12.66
# 582                      Sant Martí de Provençals                  10.83
# 583                           la Verneda i la Pau                  10.38
#
# [584 rows x 2 columns]

# %%
#safe the file
rental.to_csv("../datasets/Data_filtered/rental.csv")

# %%
tenants.head() #Nom_Barri,Ocupació_mitjana
# Out:
#     Any  Codi_Districte Nom_Districte  Codi_Barri  \
# 0  2017               1  Ciutat Vella           1
# 1  2017               1  Ciutat Vella           2
# 2  2017               1  Ciutat Vella           3
# 3  2017               1  Ciutat Vella           4
# 4  2017               2      Eixample           5
#
#                                Nom_Barri  Poblacio  Nombre_domicilis  \
# 0                               el Raval     47986             17090
# 1                         el Barri Gòtic     16240              6537
# 2                         la Barceloneta     15101              6911
# 3  Sant Pere, Santa Caterina i la Ribera     22923             10154
# 4                          el Fort Pienc     32048             12838
#
#    Ocupacio_mitjana
# 0               2.8
# 1               2.5
# 2               2.2
# 3               2.3
# 4               2.5

# %%
tenants=tenants[["Nom_Barri","Ocupacio_mitjana"]]

# %%
tenants.rename(columns={"Nom_Barri":"Nbh","Ocupacio_mitjana":"Avg_hab_per_house"})
# Out:
#                                              Nbh  Avg_hab_per_house
# 0                                       el Raval                2.8
# 1                                 el Barri Gòtic                2.5
# 2                                 la Barceloneta                2.2
# 3          Sant Pere, Santa Caterina i la Ribera                2.3
# 4                                  el Fort Pienc                2.5
# ..                                           ...                ...
# 68  Diagonal Mar i el Front Marítim del Poblenou                2.5
# 69                         el Besòs i el Maresme                2.8
# 70                       Provençals del Poblenou                2.5
# 71                      Sant Martí de Provençals                2.5
# 72                           la Verneda i la Pau                2.5
#
# [73 rows x 2 columns]

# %%
tenants.to_csv("../datasets/Data_filtered/tenants.csv")
