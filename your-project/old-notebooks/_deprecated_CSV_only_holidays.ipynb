# %%
import pandas as pd
import numpy as np
import os

# %%
#os.chdir("/Users/ainegates/Desktop/Ironhack/2nd_Week/Project-Week-2-Barcelona")

# %%
accidents = pd.read_csv("datasets/1.-Transportation/accidents-2017.csv")

# %%
#DONE
st_juan = accidents[(accidents["Month"] == "June") & (accidents["Day"].isin([23, 24]))]

# %%
#DONE
merce = accidents[(accidents["Month"] == "September") & (accidents["Day"].isin([22, 23, 24, 25]))]

# %%
juan_merce = st_juan.append(merce)

# %%
#DONE
christmas = accidents[(accidents["Month"] == "December") & (accidents["Day"].isin([24, 25]))]

# %%
juan_merce_xmas = juan_merce.append(christmas)

# %%
#DONE
Dec_6_8 = accidents[(accidents["Month"] == "December") & (accidents["Day"].isin([6, 7, 8]))]

# %%
juan_merce_xmas_dec6 = juan_merce_xmas.append(Dec_6_8)

# %%
#DONE
holy_week = accidents[(accidents["Month"] == "April") & (accidents["Day"].isin([14, 15, 16, 17]))]

# %%
juan_merce_xmas_dec6_hweek = juan_merce_xmas_dec6.append(holy_week)

# %%
#DONE
day_of_catalonia_long_weekend = accidents[(accidents["Month"] == "September") & (accidents["Day"].isin([8, 9, 10, 11]))]

# %%
juan_merce_xmas_dec6_hweek_dofcw = juan_merce_xmas_dec6_hweek.append(day_of_catalonia_long_weekend)

# %%
#DONE
NYE = accidents[(accidents["Month"] == "December") & (accidents["Day"].isin([31]))]

# %%
juan_merce_xmas_dec6_hweek_dofcw_nye = juan_merce_xmas_dec6_hweek_dofcw.append(NYE)

# %%
#DONE
new_years = accidents[(accidents["Month"] == "January") & (accidents["Day"].isin([1]))]

# %%
juan_merce_xmas_dec6_hweek_dofcw_nye_ny = juan_merce_xmas_dec6_hweek_dofcw_nye.append(new_years)

# %%
new_change = juan_merce_xmas_dec6_hweek_dofcw_nye_ny
new_change
# Out:
#                    Id   District Name                  Neighborhood Name  \
# 162   2017S005486        Ciutat Vella                           el Raval
# 284   2017S005492            Eixample     la Nova Esquerra de l'Eixample
# 411   2017S005488            Eixample    l'Antiga Esquerra de l'Eixample
# 577   2017S005505            Eixample             la Dreta de l'Eixample
# 730   2017S005504      Sants-Montjuïc              la Font de la Guatlla
# ...               ...             ...                                ...
# 6984  2017S000016            Eixample                      el Fort Pienc
# 9164  2017S000017          Sant Martí            Provençals del Poblenou
# 9171  2017S000019          Sant Martí                        el Poblenou
# 9187  2017S000005          Sant Martí  el Parc i la Llacuna del Poblenou
# 9244  2017S000011          Sant Martí      la Vila Olímpica del Poblenou
#
#                                                  Street Weekday    Month  Day  \
# ...

# %%
kings_day = accidents[(accidents["Month"] == "January") & (accidents["Day"].isin([6, 7]))]

# %%
new_change2 = new_change.append(kings_day)

# %%
first_may_longweekend1 = accidents[(accidents["Month"] == "April") & (accidents["Day"].isin([28, 29, 30]))]

# %%
new_change3 = new_change2.append(first_may_longweekend1)

# %%
first_may_longweekend2 = accidents[(accidents["Month"] == "May") & (accidents["Day"].isin([1]))]

# %%
new_change4 = new_change3.append(first_may_longweekend2)
new_change4
# Out:
#                     Id   District Name                Neighborhood Name  \
# 162    2017S005486        Ciutat Vella                         el Raval
# 284    2017S005492            Eixample   la Nova Esquerra de l'Eixample
# 411    2017S005488            Eixample  l'Antiga Esquerra de l'Eixample
# 577    2017S005505            Eixample           la Dreta de l'Eixample
# 730    2017S005504      Sants-Montjuïc            la Font de la Guatlla
# ...                ...             ...                              ...
# 6292   2017S003852          Nou Barris                 la Trinitat Nova
# 7974   2017S003856        Ciutat Vella                   la Barceloneta
# 8172   2017S003858            Eixample           la Dreta de l'Eixample
# 8252   2017S003848            Eixample           la Dreta de l'Eixample
# 10077  2017S003859              Gràcia                la Vila de Gràcia
#
#                                                   Street Weekday Month  Day  \
# ...

# %%
second_monday_lw = accidents[(accidents["Month"] == "June") & (accidents["Day"].isin([2, 3, 4, 5]))]

# %%
new_change5 = new_change4.append(second_monday_lw)

# %%
august_15th = accidents[(accidents["Month"] == "August") & (accidents["Day"].isin([15]))]

# %%
new_change6 = new_change5.append(august_15th)

# %%
october_12th = accidents[(accidents["Month"] == "October") & (accidents["Day"].isin([12]))]

# %%
new_change7 = new_change6.append(october_12th)
new_change7
# Out:
#                    Id        District Name                Neighborhood Name  \
# 162   2017S005486             Ciutat Vella                         el Raval
# 284   2017S005492                 Eixample   la Nova Esquerra de l'Eixample
# 411   2017S005488                 Eixample  l'Antiga Esquerra de l'Eixample
# 577   2017S005505                 Eixample           la Dreta de l'Eixample
# 730   2017S005504           Sants-Montjuïc            la Font de la Guatlla
# ...               ...                  ...                              ...
# 7993  2017S008385                 Eixample   la Nova Esquerra de l'Eixample
# 9234  2017S008415               Sant Martí    la Vila Olímpica del Poblenou
# 9353  2017S008420                 Eixample   la Nova Esquerra de l'Eixample
# 9838  2017S008419                Les Corts                        les Corts
# 9983  2017S008417      Sarrià-Sant Gervasi                  les Tres Torres
#
# ...

# %%
novemeber_1st = accidents[(accidents["Month"] == "November") & (accidents["Day"].isin([1]))]

# %%
new_change8 = new_change7.append(novemeber_1st)

# %%
sant_esteve = accidents[(accidents["Month"] == "December") & (accidents["Day"].isin([26]))]

# %%
new_change9 = new_change8.append(sant_esteve)

# %%
st_jordi = accidents[(accidents["Month"] == "April") & (accidents["Day"].isin([23]))]

# %%
new_change10 = new_change9.append(st_jordi)

# %%
valentines_day = accidents[(accidents["Month"] == "February") & (accidents["Day"].isin([14]))]

# %%
new_change11 = new_change10.append(valentines_day)
new_change11
# Out:
#                     Id        District Name                Neighborhood Name  \
# 162    2017S005486             Ciutat Vella                         el Raval
# 284    2017S005492                 Eixample   la Nova Esquerra de l'Eixample
# 411    2017S005488                 Eixample  l'Antiga Esquerra de l'Eixample
# 577    2017S005505                 Eixample           la Dreta de l'Eixample
# 730    2017S005504           Sants-Montjuïc            la Font de la Guatlla
# ...                ...                  ...                              ...
# 9577   2017S001224                 Eixample           la Dreta de l'Eixample
# 9902   2017S001218                Les Corts                        Pedralbes
# 9914   2017S001255      Sarrià-Sant Gervasi           Sant Gervasi - Galvany
# 10166  2017S001238           Horta-Guinardó                        el Carmel
# 10175  2017S001223           Horta-Guinardó                        el Carmel
#
# ...

# %%
new_change11.to_csv("datasets/1.-Transportation/holidays_without_cleaning_good_version.csv")

# %%
holidays = pd.read_csv("datasets/1.-Transportation/holidays_without_cleaning_good_version.csv")
holidays
# Out:
#      Unnamed: 0               Id        District Name  \
# 0           162  2017S005486             Ciutat Vella
# 1           284  2017S005492                 Eixample
# 2           411  2017S005488                 Eixample
# 3           577  2017S005505                 Eixample
# 4           730  2017S005504           Sants-Montjuïc
# ..          ...              ...                  ...
# 683        9577  2017S001224                 Eixample
# 684        9902  2017S001218                Les Corts
# 685        9914  2017S001255      Sarrià-Sant Gervasi
# 686       10166  2017S001238           Horta-Guinardó
# 687       10175  2017S001223           Horta-Guinardó
#
#                    Neighborhood Name  \
# 0                           el Raval
# 1     la Nova Esquerra de l'Eixample
# 2    l'Antiga Esquerra de l'Eixample
# 3             la Dreta de l'Eixample
# 4              la Font de la Guatlla
# ..                               ...
# 683           la Dreta de l'Eixample
# ...

# %%
holidays.columns
# Out:
# Index(['Unnamed: 0', 'Id', 'District Name', 'Neighborhood Name', 'Street',
#        'Weekday', 'Month', 'Day', 'Hour', 'Part of the day', 'Mild injuries',
#        'Serious injuries', 'Victims', 'Vehicles involved', 'Longitude',
#        'Latitude'],
#       dtype='object')

# %%
holidays.drop(["Unnamed: 0", "Id", "Neighborhood Name", "Street", "Hour", "Longitude", "Latitude"], axis=1, inplace=True)

# %%
holidays
# Out:
#            District Name  Weekday     Month  Day Part of the day  \
# 0           Ciutat Vella   Friday      June   23           Night
# 1               Eixample   Friday      June   23         Morning
# 2               Eixample   Friday      June   23         Morning
# 3               Eixample   Friday      June   23       Afternoon
# 4         Sants-Montjuïc   Friday      June   23       Afternoon
# ..                   ...      ...       ...  ...             ...
# 683             Eixample  Tuesday  February   14         Morning
# 684            Les Corts  Tuesday  February   14         Morning
# 685  Sarrià-Sant Gervasi  Tuesday  February   14       Afternoon
# 686       Horta-Guinardó  Tuesday  February   14       Afternoon
# 687       Horta-Guinardó  Tuesday  February   14         Morning
#
#      Mild injuries  Serious injuries  Victims  Vehicles involved
# 0                1                 0        1                  1
# ...

# %%
holidays.to_csv("datasets/1.-Transportation/clean_holidays.csv")
