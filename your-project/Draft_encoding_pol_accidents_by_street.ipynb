# %% [markdown]
# # ACCIDENTS AND VICTIMS BY STREET

# %%
#Import libraries
import pandas as pd
import numpy as np

# %%
#Import dataframe of streets of Barcelona and storing raw data as copy
streets_raw = pd.read_csv('../datasets/0401230100_BCN_Nomenclàtor.csv')
streets = streets_raw.copy()
streets.head()
# Out:
#      CODI TIPUS_VIA PARTICULES               NOM  DATA_APROV NOTES_DATA  \
# 0  701599   jardins         d'         Ada Byron  24/04/2007        NaN
# 1    2050    carrer         d'    Adolf Florensa  28/07/1982        NaN
# 2  701657     plaça         d'  Adolf Marsillach  07/11/2008        NaN
# 3  540074      moll        NaN           Adossat         NaN        NaN
# 4    2200    carrer         d'            Adrall  29/05/1945        NaN
#
#                                          DESCRIPCIO1  DESCRIPCIO2 FONTS_DOC  \
# 0  Augusta Ada Byron (Londres, 1815 - 1852). Cone...          NaN       NaN
# 1  Adolf Florensa i Ferrer (Lleida, 1889 - Barcel...          NaN  {PC:en}.
# 2  Adolf Marsillach i Soriano (Barcelona, 1928 - ...          NaN       NaN
# 3  Per haver-se adossat tot al llarg del dic de l...          NaN    {APB}.
# 4  Poble del municipi de la parròquia d'Hortó (Al...          NaN    {n80}.
#
#   ALTRES_NOMS
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4     Núm. 40

# %%
#Created a new column with a concatenation of 3 columns: TIPUS_VIA, PARTICULES, NOM
streets['Complete_name'] = streets['TIPUS_VIA'].str.capitalize().str.cat([streets['PARTICULES'], streets['NOM']], sep= ' ', na_rep = '')

streets_clean = streets[['CODI', 'Complete_name']]
streets_clean.columns = ['Codi_carrer', 'Complete_name']

streets_clean
# Out:
#       Codi_carrer                        Complete_name
# 0          701599                 Jardins d' Ada Byron
# 1            2050             Carrer d' Adolf Florensa
# 2          701657            Plaça d' Adolf Marsillach
# 3          540074                        Moll  Adossat
# 4            2200                     Carrer d' Adrall
# ...           ...                                  ...
# 4539       701879    Placeta d' Angelina Alòs i Tormos
# 4540       701880  Jardins de Maria Carbonell i Mumbrú
# 4541       701845                 Carrer de Neus Bouzá
# 4542       701846              Plaça d' Humberto Rivas
# 4543       701847         Plaça del Doctor Matias Guiu
#
# [4544 rows x 2 columns]

# %%
#Imported the dataframe acc_clean from the other Notebook.
acc_clean = pd.read_csv('../datasets/acc_clean.csv', index_col = 0)
acc_clean.head()
acc_clean
# Out:
#       Numero_expedient        Nom_districte  \
# 0      2019S000001      Sarrià-Sant Gervasi
# 1      2019S000002              Sant Andreu
# 2      2019S000003               Sant Martí
# 3      2019S000004                   Gràcia
# 4      2019S000005                 Eixample
# ...                ...                  ...
# 10022  2019S010046                Les Corts
# 10023  2019S010047               Sant Martí
# 10024  2019S010048                 Eixample
# 10025  2019S010049                Les Corts
# 10026  2019S010050                 Eixample
#
#                                 Nom_barri  Codi_carrer Dia_setmana  NK_Any  \
# 0                  Sant Gervasi - Galvany       144601          Dm    2019
# 1                el Congrés i els Indians       102907          Dm    2019
# 2       el Parc i la Llacuna del Poblenou       242906          Dm    2019
# 3      el Camp d'en Grassot i Gràcia Nova       228803          Dm    2019
# 4                  la Dreta de l'Eixample        89004          Dm    2019
# ...                                   ...          ...         ...     ...
# 10022                           Pedralbes       101700          Dm    2019
# 10023          el Camp de l'Arpa del Clot       297001          Dm    2019
# 10024                       el Fort Pienc        28305          Dm    2019
# 10025                           les Corts       167800          Dm    2019
# 10026                  la Sagrada Família       178308          Dc    2019
#
#        Mes_any   Nom_mes  Dia_mes  Hora_dia Descripcio_torn  Numero_morts  \
# 0            1     Gener        1         1             Nit             0
# 1            1     Gener        1         4             Nit             0
# 2            1     Gener        1         5             Nit             0
# 3            1     Gener        1         8            Matí             0
# 4            1     Gener        1        12            Matí             0
# ...        ...       ...      ...       ...             ...           ...
# 10022       12  Desembre       31        15           Tarda             0
# 10023       12  Desembre       31        19           Tarda             0
# 10024       12  Desembre       31        16           Tarda             0
# 10025       12  Desembre       31        21           Tarda             0
# 10026       11  Novembre        6         7            Matí             0
#
#        Numero_lesionats_lleus  Numero_lesionats_greus  Numero_victimes  \
# 0                           0                       1                1
# 1                           1                       0                1
# 2                           1                       0                1
# 3                           1                       0                1
# 4                           2                       0                2
# ...                       ...                     ...              ...
# 10022                       1                       0                1
# 10023                       1                       0                1
# 10024                       1                       0                1
# 10025                       1                       0                1
# 10026                       0                       1                1
#
#        Numero_vehicles_implicats         Type_day        Date
# 0                              1  Weekend/Holiday    1/1/2019
# 1                              2  Weekend/Holiday    1/1/2019
# 2                              1  Weekend/Holiday    1/1/2019
# 3                              2  Weekend/Holiday    1/1/2019
# 4                              1  Weekend/Holiday    1/1/2019
# ...                          ...              ...         ...
# 10022                          1          Weekday  31/12/2019
# 10023                          2          Weekday  31/12/2019
# 10024                          2          Weekday  31/12/2019
# 10025                          2          Weekday  31/12/2019
# 10026                          2          Weekday   6/11/2019
#
# [10027 rows x 18 columns]

# %%
# Here we get a merge (left join) between acc_clean and the streets, in order to get exactly the street's name for each accident.
streets_accidents = acc_clean.merge(streets_clean, how = 'left', on = 'Codi_carrer' )
streets_accidents.head()
# Out:
#   Numero_expedient        Nom_districte                           Nom_barri  \
# 0  2019S000001      Sarrià-Sant Gervasi              Sant Gervasi - Galvany
# 1  2019S000002              Sant Andreu            el Congrés i els Indians
# 2  2019S000003               Sant Martí   el Parc i la Llacuna del Poblenou
# 3  2019S000004                   Gràcia  el Camp d'en Grassot i Gràcia Nova
# 4  2019S000005                 Eixample              la Dreta de l'Eixample
#
#    Codi_carrer Dia_setmana  NK_Any  Mes_any Nom_mes  Dia_mes  Hora_dia  \
# 0       144601          Dm    2019        1   Gener        1         1
# 1       102907          Dm    2019        1   Gener        1         4
# 2       242906          Dm    2019        1   Gener        1         5
# 3       228803          Dm    2019        1   Gener        1         8
# 4        89004          Dm    2019        1   Gener        1        12
#
#   Descripcio_torn  Numero_morts  Numero_lesionats_lleus  \
# 0             Nit             0                       0
# 1             Nit             0                       1
# 2             Nit             0                       1
# 3            Matí             0                       1
# 4            Matí             0                       2
#
#    Numero_lesionats_greus  Numero_victimes  Numero_vehicles_implicats  \
# 0                       1                1                          1
# 1                       0                1                          2
# 2                       0                1                          1
# 3                       0                1                          2
# 4                       0                2                          1
#
#           Type_day      Date               Complete_name
# 0  Weekend/Holiday  1/1/2019          Avinguda  Diagonal
# 1  Weekend/Holiday  1/1/2019    Plaça del Doctor Modrego
# 2  Weekend/Holiday  1/1/2019           Carrer de Pallars
# 3  Weekend/Holiday  1/1/2019          Passatge de Nogués
# 4  Weekend/Holiday  1/1/2019  Carrer del Consell de Cent

# %%
# Now we get the grouby by street name, in a similar way as the notebook about accidents by day/hour or month.
streets_accidents_grouped=streets_accidents.groupby('Complete_name').aggregate({'Numero_expedient': 'count', 'Numero_victimes': 'sum', 
                                                      'Numero_vehicles_implicats': 'sum', 'Numero_lesionats_lleus':'sum', 
                                                      'Numero_lesionats_greus':'sum', 'Numero_morts':'sum'})
streets_accidents_grouped.columns = ['Accidents', 'Total_Victims', 'Total_Vehicles', 'Minor_Injuries', 'Severe_Injuries', 'Deaths']
streets_accidents_grouped.index.name= 'Street_name'

streets_accidents_grouped_perc = streets_accidents_grouped.apply(lambda x: round (100 * x / x.sum(),2))
streets_accidents_grouped_perc.columns = ['%Accidents', '%Total_Victims', '%Total_Vehicles', '%Minor_Injuries', '%Severe_Injuries', '%Deaths']


streets_accidents_grouped = pd.concat([streets_accidents_grouped,streets_accidents_grouped_perc], axis =1)
streets_accidents_grouped = streets_accidents_grouped[['Accidents', '%Accidents', 'Total_Victims', '%Total_Victims', 'Total_Vehicles', '%Total_Vehicles', 'Minor_Injuries',
       '%Minor_Injuries', 'Severe_Injuries', '%Severe_Injuries', 'Deaths', '%Deaths']]
streets_accidents_grouped
# Out:
#                               Accidents  %Accidents  Total_Victims  \
# Street_name
#  la Rambla                           35        0.39             23
# Avinguda  Diagonal                  426        4.72            539
# Avinguda  Meridiana                 199        2.21            251
# Avinguda d' Albert Bastardas          5        0.06              9
# Avinguda d' Eduard Maristany          1        0.01              1
# ...                                 ...         ...            ...
# Via  Júlia                            8        0.09              8
# Via  Laietana                        37        0.41             41
# Via  Trajana                          3        0.03              3
# Via de Bàrcino                        7        0.08              7
# Viaducte de Vallcarca                 1        0.01              2
#
#                               %Total_Victims  Total_Vehicles  %Total_Vehicles  \
# Street_name
#  la Rambla                              0.22              58             0.34
# Avinguda  Diagonal                      5.14             809             4.79
# Avinguda  Meridiana                     2.39             384             2.27
# Avinguda d' Albert Bastardas            0.09              13             0.08
# Avinguda d' Eduard Maristany            0.01               2             0.01
# ...                                      ...             ...              ...
# Via  Júlia                              0.08              13             0.08
# Via  Laietana                           0.39              74             0.44
# Via  Trajana                            0.03               5             0.03
# Via de Bàrcino                          0.07              13             0.08
# Viaducte de Vallcarca                   0.02               1             0.01
#
#                               Minor_Injuries  %Minor_Injuries  \
# Street_name
#  la Rambla                                23             0.22
# Avinguda  Diagonal                       523             5.08
# Avinguda  Meridiana                      249             2.42
# Avinguda d' Albert Bastardas               9             0.09
# Avinguda d' Eduard Maristany               1             0.01
# ...                                      ...              ...
# Via  Júlia                                 8             0.08
# Via  Laietana                             40             0.39
# Via  Trajana                               3             0.03
# Via de Bàrcino                             7             0.07
# Viaducte de Vallcarca                      2             0.02
#
#                               Severe_Injuries  %Severe_Injuries  Deaths  \
# Street_name
#  la Rambla                                  0              0.00       0
# Avinguda  Diagonal                         16              9.25       0
# Avinguda  Meridiana                         2              1.16       0
# Avinguda d' Albert Bastardas                0              0.00       0
# Avinguda d' Eduard Maristany                0              0.00       0
# ...                                       ...               ...     ...
# Via  Júlia                                  0              0.00       0
# Via  Laietana                               1              0.58       0
# Via  Trajana                                0              0.00       0
# Via de Bàrcino                              0              0.00       0
# Viaducte de Vallcarca                       0              0.00       0
#
#                               %Deaths
# Street_name
#  la Rambla                        0.0
# Avinguda  Diagonal                0.0
# Avinguda  Meridiana               0.0
# Avinguda d' Albert Bastardas      0.0
# Avinguda d' Eduard Maristany      0.0
# ...                               ...
# Via  Júlia                        0.0
# Via  Laietana                     0.0
# Via  Trajana                      0.0
# Via de Bàrcino                    0.0
# Viaducte de Vallcarca             0.0
#
# [1124 rows x 12 columns]

# %% [markdown]
# ### Accidents by street

# %%
# Get the values of the resulting table sorted by number of accidents.
streets_accidents_grouped[['Accidents','%Accidents']].sort_values('Accidents', ascending=False).head(5)
# Out:
#                                  Accidents  %Accidents
# Street_name
# Gran via de les Corts Catalanes        523        5.80
# Avinguda  Diagonal                     426        4.72
# Carrer d' Aragó                        333        3.69
# Avinguda  Meridiana                    199        2.21
# Carrer de València                     175        1.94

# %% [markdown]
# ### Total victims by street

# %%
streets_accidents_grouped[['Total_Victims','%Total_Victims']].sort_values('Total_Victims', ascending=False).head(5)
# Out:
#                                  Total_Victims  %Total_Victims
# Street_name
# Gran via de les Corts Catalanes            639            6.09
# Avinguda  Diagonal                         539            5.14
# Carrer d' Aragó                            401            3.82
# Avinguda  Meridiana                        251            2.39
# Carrer de València                         204            1.94

# %% [markdown]
# ### Severe injuries by street

# %%
streets_accidents_grouped[['Severe_Injuries','%Severe_Injuries']].sort_values('Severe_Injuries', ascending=False).head(5)
# Out:
#                                  Severe_Injuries  %Severe_Injuries
# Street_name
# Avinguda  Diagonal                            16              9.25
# Carrer d' Aragó                               10              5.78
# Gran via de les Corts Catalanes                6              3.47
# Passeig de la Vall d'Hebron                    5              2.89
# Carretera de Sant Cugat                        5              2.89

# %% [markdown]
# ### Deaths by street

# %%
streets_accidents_grouped[['Deaths','%Deaths']].sort_values('Deaths', ascending=False).head(5)
# Out:
#                                  Deaths  %Deaths
# Street_name
# Gran via de les Corts Catalanes       2    11.11
# Ronda del General Mitre               1     5.56
# Carrer de Provençals                  1     5.56
# Carrer de la Marina                   1     5.56
# Carrer de Pau Alsina\r\n              1     5.56
