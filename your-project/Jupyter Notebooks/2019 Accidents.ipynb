# %%
import pandas as pd

# %%
accidents = pd.read_csv("../datasets/1.-Transportation/2019_accidents_vehicles_gu_bcn_.csv")

# %%
accidents.head()
# Out:
#   Numero_expedient  Codi_districte Nom_districte  Codi_barri   Nom_barri  \
# 0  2019S005075                  -1    Desconegut          -1  Desconegut
# 1  2019S005075                  -1    Desconegut          -1  Desconegut
# 2  2019S008513                  -1    Desconegut          -1  Desconegut
# 3  2019S001554                  -1    Desconegut          -1  Desconegut
# 4  2019S001554                  -1    Desconegut          -1  Desconegut
#
#    Codi_carrer                                         Nom_carrer Num_postal  \
# 0           -1  Comte d'Urgell / Roma                         ...        NaN
# 1           -1                                                NaN        NaN
# 2           -1  Número 50 Zona Franca / Número 3 Zona Franca  ...        NaN
# 3           -1  A Zona Franca / Número 3 Zona Franca          ...        NaN
# 4           -1                                                NaN        NaN
#
# ...

# %%
accidents_c = accidents.rename(columns= {"Numero_expedient": "Expedient Number", "Nom_districte":"District Name",
                           "Nom_barri": "Neighborhood Name", "Nom_carrer": "Street Name",
                           "Dia_setmana":"Day of the Week", "Descripcio_tipus_vehicle":"Vehicle Type",
                          "Descripcio_model":"Model", "Descripcio_marca":"Brand", "Descripcio_color":"Color", "Descripcio_tipus_dia":"Day Description", "NK_Any":"Year", 
                        "Nom_mes":"Month", "Dia_mes":"Day", "Hora_dia":"Hour", 
                         "Descripcio_torn":"Part of Day", "Descripcio_causa_vianant":"Pedestrian Cause"})

# %%
accidents_c.drop(["Codi_districte", "Codi_barri", "Codi_carrer", "Num_postal", "Descripcio_carnet", "Antiguitat_carnet", "Coordenada_UTM_X", "Coordenada_UTM_Y", "Descripcio_dia_setmana", "Mes_any", "Day Description"], axis=1, inplace=True)

# %%
accidents_clean = accidents_c.rename(columns= {"Descripcio_tipus_dia":"Day Description", "NK_Any":"Year", 
                                               "Nom_mes":"Month", "Dia_mes":"Day", "Hora_dia":"Hour", 
                                               "Descripcio_torn":"Part of Day", "Descripcio_causa_vianant":"Pedestrian Cause"})

# %%
accidents_clean.drop(["Descripcio_dia_setmana", "Mes_any", "Day Description"], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-af2cb5d98378> in <module>
# ----> 1 accidents_clean.drop(["Descripcio_dia_setmana", "Mes_any", "Day Description"], axis=1, inplace=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
accidents_clean["Part of Day"] = accidents_clean["Part of Day"].replace(["Tarda"], "Afternoon")

# %%
accidents_clean["Part of Day"] = accidents_clean["Part of Day"].replace(["Matí"], "Morning")

# %%
accidents_clean["Part of Day"] = accidents_clean["Part of Day"].replace(["Nit"], "Night")

# %%
accidents_clean["Day of the Week"] = accidents_clean["Day of the Week"].replace(["Dj"], "Thursday")

# %%
accidents_clean["Day of the Week"] = accidents_clean["Day of the Week"].replace(["Dv"], "Friday")

# %%
accidents_clean["Day of the Week"] = accidents_clean["Day of the Week"].replace(["Dg"], "Sunday")

# %%
accidents_clean["Day of the Week"] = accidents_clean["Day of the Week"].replace(["Dl"], "Monday")

# %%
accidents_clean["Day of the Week"] = accidents_clean["Day of the Week"].replace(["Dm"], "Tuesday")

# %%
accidents_clean["Day of the Week"] = accidents_clean["Day of the Week"].replace(["Dc"], "Wednesday")

# %%
accidents_clean["Day of the Week"] = accidents_clean["Day of the Week"].replace(["Ds"], "Saturday")

# %%
accidents_clean["Month"] = accidents_clean["Month"].replace(["Gener"], "January")

# %%
accidents_clean["Month"] = accidents_clean["Month"].replace(["Febrer"], "February")

# %%
accidents_clean["Month"] = accidents_clean["Month"].replace(["Març"], "March")

# %%
accidents_clean["Month"].unique()
# Out:
# array(['Juny', 'Novembre', 'February', 'Abril', 'Agost', 'Desembre',
#        'January', 'March', 'Juliol', 'Octubre', 'Maig', 'Setembre'],
#       dtype=object)

# %%
accidents_clean["Month"] = accidents_clean["Month"].replace(["Abril"], "April")

# %%
accidents_clean["Month"] = accidents_clean["Month"].replace(["Maig"], "May")

# %%
accidents_clean["Month"] = accidents_clean["Month"].replace(["Juny"], "June")

# %%
accidents_clean["Month"] = accidents_clean["Month"].replace(["Juny"], "June")

# %%
accidents_clean["Month"] = accidents_clean["Month"].replace(["Juliol"], "July")

# %%
accidents_clean["Month"] = accidents_clean["Month"].replace(["Agost"], "August")

# %%
accidents_clean["Month"] = accidents_clean["Month"].replace(["Setembre"], "September")

# %%
accidents_clean["Month"] = accidents_clean["Month"].replace(["Octubre"], "October")

# %%
accidents_clean["Month"] = accidents_clean["Month"].replace(["Novembre"], "November")

# %%
accidents_clean["Month"] = accidents_clean["Month"].replace(["Desembre"], "December")

# %%
accidents_clean["Color"].value_counts()
# Out:
# Blanc         4087
# Negre         4064
# Gris          3430
# Desconegut    3032
# Vermell       1344
# Blau          1083
# Negre/Groc     872
# Verd           296
# Groc           168
# Altres         160
# granate        152
# Marró           97
# Taronja         92
# Platejat        66
# Beige           32
# Daurat          22
# Violeta         21
# Rosa             7
# Name: Color, dtype: int64

# %%
accidents_clean["Color"] = accidents_clean["Color"].replace(["Blanc"], "White")

# %%
accidents_clean["Color"] = accidents_clean["Color"].replace(["Negre"], "Black")

# %%
accidents_clean["Color"] = accidents_clean["Color"].replace(["Gris"], "Grey")

# %%
accidents_clean["Color"] = accidents_clean["Color"].replace(["Desconegut"], "Unknown")

# %%
accidents_clean["Color"] = accidents_clean["Color"].replace(["Vermell"], "Red")

# %%
accidents_clean["Color"] = accidents_clean["Color"].replace(["Blau"], "Blue")

# %%
accidents_clean["Vehicle Type"].value_counts()
# Out:
# Turisme                                7420
# Motocicleta                            6064
# Furgoneta                              1228
# Ciclomotor                              951
# Bicicleta                               786
# Taxi                                    643
# Veh. mobilitat personal amb motor       486
# Autobús                                 453
# Camió rígid <= 3,5 tones                238
# Camió rígid > 3,5 tones                 180
# Tot terreny                             150
# Autobús articulat                       130
# Tractor camió                            84
# Desconegut                               58
# Veh. mobilitat personal sense motor      49
# Altres vehicles amb motor                33
# Autocar                                  22
# Maquinària d'obres i serveis             21
# Tren o tramvia                            9
# Altres vehicles sense motor               7
# Pick-up                                   5
# ...

# %%
accidents_clean["Neighborhood Name"].value_counts()
# Out:
# la Dreta de l'Eixample             2240
# l'Antiga Esquerra de l'Eixample    1109
# Sant Gervasi - Galvany              817
# la Nova Esquerra de l'Eixample      766
# la Sagrada Família                  694
#                                    ...
# Can Baró                             25
# Torre Baró                           22
# Ciutat Meridiana                     16
# Vallbona                             13
# Can Peguera                           9
# Name: Neighborhood Name, Length: 74, dtype: int64

# %%
accidents_clean["Pedestrian Cause"].value_counts()
# Out:
# No és causa del  vianant           18286
# Creuar per fora pas de vianants      253
# Desobeir el senyal del semàfor       252
# Altres                               182
# Transitar a peu per la calçada        56
# Desobeir altres senyals                8
# Name: Pedestrian Cause, dtype: int64

# %%
accidents_clean["Pedestrian Cause"] = accidents_clean["Pedestrian Cause"].replace(["No és causa del  vianant"], "Not caused by pedestrian")

# %%
accidents_clean["Pedestrian Cause"] = accidents_clean["Pedestrian Cause"].replace(["Creuar per fora pas de vianants"], "Cross outside pedestrian crossing")

# %%
accidents_clean["Pedestrian Cause"] = accidents_clean["Pedestrian Cause"].replace(["Desobeir el senyal del semàfor"], "Disobey the traffic light signal")

# %%
accidents_clean["Pedestrian Cause"] = accidents_clean["Pedestrian Cause"].replace(["Altres"], "Others")

# %%
accidents_clean["Pedestrian Cause"] = accidents_clean["Pedestrian Cause"].replace(["Transitar a peu per la calçada"], "Walk along the road")

# %%
accidents_clean["Pedestrian Cause"] = accidents_clean["Pedestrian Cause"].replace(["Desobeir altres senyals"], "Disobey other signs")

# %%
accidents_clean["Pedestrian Cause"].value_counts()
# Out:
# Not caused by pedestrian             18286
# Cross outside pedestrian crossing      253
# Disobey the traffic light signal       252
# Others                                 182
# Walk along the road                     56
# Disobey other signs                      8
# Name: Pedestrian Cause, dtype: int64

# %%
accidents_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19037 entries, 0 to 19036
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Expedient Number   19025 non-null  object
#  1   District Name      19037 non-null  object
#  2   Neighborhood Name  19037 non-null  object
#  3   Street Name        19021 non-null  object
#  4   Day of the Week    19037 non-null  object
#  5   Year               19037 non-null  int64
#  6   Month              19037 non-null  object
#  7   Day                19037 non-null  int64
#  8   Hour               19037 non-null  int64
#  9   Part of Day        18881 non-null  object
#  10  Pedestrian Cause   19037 non-null  object
#  11  Vehicle Type       19025 non-null  object
#  12  Model              19024 non-null  object
#  13  Brand              19025 non-null  object
#  14  Color              19025 non-null  object
#  15  Longitud           19037 non-null  float64
# ...

# %%
accidents_clean["Part of Day"].value_counts()
# Out:
# Afternoon    9539
# Morning      7277
# Night        2065
# Name: Part of Day, dtype: int64

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)
accidents_clean.groupby(["Neighborhood Name", "Part of Day"]).count()
# Out:
#                                                           Expedient Number  \
# Neighborhood Name                            Part of Day
# Baró de Viver                                Afternoon                  21
#                                              Morning                    15
#                                              Night                       8
# Can Baró                                     Afternoon                  18
#                                              Morning                     5
#                                              Night                       2
# Can Peguera                                  Afternoon                   3
#                                              Morning                     3
#                                              Night                       3
# Canyelles                                    Afternoon                  48
#                                              Morning                    27
# ...

# %%
accidents_clean
# Out:
#       Expedient Number District Name    Neighborhood Name  \
# 0      2019S005075        Desconegut           Desconegut
# 1      2019S005075        Desconegut           Desconegut
# 2      2019S008513        Desconegut           Desconegut
# 3      2019S001554        Desconegut           Desconegut
# 4      2019S001554        Desconegut           Desconegut
# ...                ...           ...                  ...
# 19032  2019S009159        Sant Martí  la Verneda i la Pau
# 19033  2019S008097        Sant Martí  la Verneda i la Pau
# 19034  2019S008097        Sant Martí  la Verneda i la Pau
# 19035  2019S004224        Sant Martí  la Verneda i la Pau
# 19036  2019S007426        Sant Martí  la Verneda i la Pau
#
#                                              Street Name Day of the Week  \
# 0      Comte d'Urgell / Roma                         ...        Thursday
# 1                                                    NaN        Thursday
# ...

# %%
accidents_clean["Brand"].value_counts()
# Out:
# HONDA         2633
# SEAT          1012
# YAMAHA         914
# Desconegut     874
# PEUGEOT        821
#               ...
# MAURICIO         1
# GARELLI          1
# FRUMECAR         1
# VECTRIX          1
# TERRADAS         1
# Name: Brand, Length: 221, dtype: int64

# %%
accidents_clean["Day of the Week"].value_counts()
# Out:
# Friday       3164
# Wednesday    3160
# Thursday     3122
# Tuesday      3095
# Monday       2846
# Saturday     2070
# Sunday       1580
# Name: Day of the Week, dtype: int64

# %%
accidents_clean["Part of Day"].value_counts()
# Out:
# Afternoon    9539
# Morning      7277
# Night        2065
# Name: Part of Day, dtype: int64

# %%
accidents_clean["District Name"].value_counts()
# Out:
# Eixample               5787
# Sant Martí             2449
# Sants-Montjuïc         2198
# Sarrià-Sant Gervasi    2052
# Les Corts              1289
# Sant Andreu            1209
# Horta-Guinardó         1204
# Ciutat Vella            986
# Nou Barris              979
# Gràcia                  850
# Desconegut               34
# Name: District Name, dtype: int64

# %%
accidents_clean.head()
# Out:
#   Expedient Number District Name Neighborhood Name  \
# 0  2019S005075        Desconegut        Desconegut
# 1  2019S005075        Desconegut        Desconegut
# 2  2019S008513        Desconegut        Desconegut
# 3  2019S001554        Desconegut        Desconegut
# 4  2019S001554        Desconegut        Desconegut
#
#                                          Street Name Day of the Week  Year  \
# 0  Comte d'Urgell / Roma                         ...        Thursday  2019
# 1                                                NaN        Thursday  2019
# 2  Número 50 Zona Franca / Número 3 Zona Franca  ...          Monday  2019
# 3  A Zona Franca / Número 3 Zona Franca          ...         Tuesday  2019
# 4                                                NaN         Tuesday  2019
#
#       Month  Day  Hour Part of Day          Pedestrian Cause Vehicle Type  \
# 0      June   27    18   Afternoon  Not caused by pedestrian    Bicicleta
# ...

# %%
accidents_clean["Month"].value_counts()
# Out:
# July         1800
# May          1778
# March        1693
# June         1690
# October      1687
# January      1600
# November     1593
# April        1568
# February     1562
# December     1439
# September    1410
# August       1217
# Name: Month, dtype: int64
