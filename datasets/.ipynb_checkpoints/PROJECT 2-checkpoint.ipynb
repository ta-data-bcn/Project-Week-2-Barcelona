# %%
import pandas as pd

# %%
nacionality = pd.read_csv('/Users/andressalomferrer/Desktop/ironhack/Projects/Project-Week-2-Barcelona/datasets/3.-Population/immigrants-by-nationality.csv')

# %%
a
# Out:
#        Year  District Code        District Name  Neighborhood Code  \
# 0      2017              1         Ciutat Vella                  1
# 1      2017              1         Ciutat Vella                  2
# 2      2017              1         Ciutat Vella                  3
# 3      2017              1         Ciutat Vella                  4
# 4      2017              2             Eixample                  5
# 5      2017              2             Eixample                  6
# 6      2017              2             Eixample                  7
# 7      2017              2             Eixample                  8
# 8      2017              2             Eixample                  9
# 9      2017              2             Eixample                 10
# 10     2017              3       Sants-Montjuïc                 11
# 11     2017              3       Sants-Montjuïc                 12
# 12     2017              3       Sants-Montjuïc                 13
# ...

# %%
b = pd.read_csv('/Users/andressalomferrer/Desktop/ironhack/Projects/Project-Week-2-Barcelona/datasets/2018_immigrants_edats-quinquennals.csv')

# %%
b
# Out:
#        Any  Codi_districte        Nom_districte  Codi_barri  \
# 0     2018               1         Ciutat Vella           1
# 1     2018               1         Ciutat Vella           2
# 2     2018               1         Ciutat Vella           3
# 3     2018               1         Ciutat Vella           4
# 4     2018               2             Eixample           5
# 5     2018               2             Eixample           6
# 6     2018               2             Eixample           7
# 7     2018               2             Eixample           8
# 8     2018               2             Eixample           9
# 9     2018               2             Eixample          10
# 10    2018               3       Sants-Montjuïc          11
# 11    2018               3       Sants-Montjuïc          12
# 12    2018               3       Sants-Montjuïc          13
# 13    2018               3       Sants-Montjuïc          14
# 14    2018               3       Sants-Montjuïc          15
# ...
