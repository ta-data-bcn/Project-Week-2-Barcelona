# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot

# %%
population_per_neighborhood = pd.read_csv("2019_domicilis_sexe.csv")

# %%
population_per_neighborhood.head()
# Out:
#     Any  Codi_districte Nom_districte  Codi_barri  \
# 0  2019               1  Ciutat Vella           1
# 1  2019               1  Ciutat Vella           2
# 2  2019               1  Ciutat Vella           3
# 3  2019               1  Ciutat Vella           4
# 4  2019               2      Eixample           5
#
#                                Nom_barri      Sexe  Nombre
# 0                               el Raval  Cap dona    4398
# 1                         el Barri Gòtic  Cap dona    1716
# 2                         la Barceloneta  Cap dona    1603
# 3  Sant Pere, Santa Caterina i la Ribera  Cap dona    2503
# 4                          el Fort Pienc  Cap dona    1900

# %%
population_per_neighborhood.columns
# Out:
# Index(['Year', 'Codi_districte', 'Nom_districte', 'Codi_barri', 'Nom_barri',
#        'Sexe', 'Nombre'],
#       dtype='object')

# %%
population_per_neighborhood = population_per_neighborhood.rename(columns = {'Any':'Year', 'Codi_districte':'District code', 'Nom_districte':'Neighborhood', 'Codi_barri':'Neighborhood code', 'Nom_barri':'Neighborhood name', 'Sexe':'Sex', 'Nombre':'Name'})

# %%
population_per_neighborhood.head()
# Out:
#    Year  District code  Neighborhood  Neighborhood code  \
# 0  2019              1  Ciutat Vella                  1
# 1  2019              1  Ciutat Vella                  2
# 2  2019              1  Ciutat Vella                  3
# 3  2019              1  Ciutat Vella                  4
# 4  2019              2      Eixample                  5
#
#                        Neighborhood name       Sex  Name
# 0                               el Raval  Cap dona  4398
# 1                         el Barri Gòtic  Cap dona  1716
# 2                         la Barceloneta  Cap dona  1603
# 3  Sant Pere, Santa Caterina i la Ribera  Cap dona  2503
# 4                          el Fort Pienc  Cap dona  1900

# %%
air_quality_June2018 = pd.read_csv("Project-Week-2-Barcelona/datasets/2.-Urban-Environment/2018_06_Juny_qualitat_aire_BCN.csv")

# %%
air_quality_July2018 = pd.read_csv("Project-Week-2-Barcelona/datasets/2.-Urban-Environment/2018_07_Juliol_qualitat_aire_BCN.csv")

# %%
air_quality_August2018 = pd.read_csv("Project-Week-2-Barcelona/datasets/2.-Urban-Environment/2018_08_Agost_qualitat_aire_BCN.csv")

# %%
air_quality_September2018 = pd.read_csv("Project-Week-2-Barcelona/datasets/2.-Urban-Environment/2018_09_Setembre_qualitat_aire_BCN.csv")

# %%
air_quality_October2018 = pd.read_csv("Project-Week-2-Barcelona/datasets/2.-Urban-Environment/2018_10_Octubre_qualitat_aire_BCN.csv")

# %%
air_quality_November2018 = pd.read_csv("Project-Week-2-Barcelona/datasets/2.-Urban-Environment/2018_11_Novembre_qualitat_aire_BCN.csv")

# %%
air_quality_December2018 = pd.read_csv("Project-Week-2-Barcelona/datasets/2.-Urban-Environment/2018_12_Desembre_qualitat_aire_BCN.csv")

# %%
air_quality_2018 = pd.concat([air_quality_June2018, air_quality_July2018, air_quality_August2018, air_quality_September2018, 
           air_quality_October2018, air_quality_November2018, air_quality_December2018], axis = 0)
air_quality_2018
# Out:
#                     nom_cabina qualitat_aire codi_dtes  zqa  codi_eoi  \
# 0            Barcelona - Sants            --        ID    1   8019042
# 1         Barcelona - Eixample          Bona        IH    1   8019043
# 2           Barcelona - Gràcia          Bona        IJ    1   8019044
# 3       Barcelona - Ciutadella          Bona        IL    1   8019050
# 4      Barcelona - Vall Hebron          Bona        IN    1   8019054
# ...                        ...           ...       ...  ...       ...
# 5843    Barcelona - Ciutadella            --        IL    1   8019050
# 5844   Barcelona - Vall Hebron          Bona        IN    1   8019054
# 5845   Barcelona - Palau Reial          Bona        IZ    1   8019057
# 5846      Barcelona - Poblenou          Bona        I2    1   8019004
# 5847  Barcelona - Observ Fabra          Bona        OF    1   8019058
#
#       longitud  latitud hora_o3 qualitat_o3  valor_o3 hora_no2 qualitat_no2  \
# ...

# %%
air_quality_2018.duplicated(keep = False)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5843    False
# 5844    False
# 5845    False
# 5846    False
# 5847    False
# Length: 35983, dtype: bool
