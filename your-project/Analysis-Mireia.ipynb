# %% [markdown]
# ## Questions to answer:
# - What could define a better or worse neighbourhood?
# - Does the quality (bad,normal,good,etc) of the neighbourhood relate with its death rate? and with the birth rate?
# - Do the neighbourhoods with higher births or higher population have more schools or hospitals? what about the other facilities (parks, sports centers,etc)

# %% [markdown]
# ### Values to analyse:
# - **Define Nbh quality**:
#     - Are there facilities more valuable than others?:
#         - top 5 for each facility
#         - worst 5
#         - top 5 **Nbh** and **Dist** with higher number of facilities
#         - worst 5
# <br><br>
# - **Quality and death rate/birth rate**
#     - top 5 Nhb and Dist with highest birth/death rates
#     - Nbh and Dist quality ranking (very bad, bad, neither, good, very good)
#     - find correlation
# <br><br>
# - **Higher birth rate Nbh and Dist have more facilities? And schools in particular?**
#     - Top 5 Nbh and Dist with highest birth rates
#     - Facilities number
#     - schools number
# <br><br>
# - **Nbh and Dist with higher population number have more facilities? And schools in particular?**
#     - Top 5 Nbh and Dist with highest population
#     - Facilities number
#     - schools number

# %%
#import libraries to work
import pandas as pd
import numpy as np

# %%
#import the cleaned dataset

Complete=pd.read_csv("../datasets/Data_filtered/complete_dataset.csv")

# %% [markdown]
# ### Description variables:
# - **nbh**: Barcelona's Neighbourhoods
# - **bars**: number of bars in 2017
# - **children_places**: number of places dedicated to children  in 2017
# - **cinemas_theatres**: number of cinemas or theatres  in 2017
# - **schools**: number of schools in 2017
# - **pre-schools**: number of pre-schools in 2017
# - **hospitals**: number of hospitals in 2017
# - **libraries**: number of libraries in 2017
# - **park_gardens**: number of parks and gardens in 2017
# - **sport_centers**: number of sports centers in 2017
# - **population**: number of people in 2017
# - **net_density(hab/ha)**: density per habitable are (habitants per habitable hectares) in 2017
# - **avg_occupation**: average number of people living in a house
# - **dist**: Barcelona's district
# - **num_immi**: number of immigrants in 2017
# - **mort_rate**: number of people that died in 2017
# - **rent_price**: price of rent per m2 in 2017
# - **num_crimes**: number of crimes during 2017

# %%
#Have a quick look
Complete.head(10)
# Out:
#                                      nbh  bars  children_places  \
# 0                                  Horta   4.0             20.0
# 1                                  Navas   2.0              8.0
# 2                              Pedralbes   1.0             14.0
# 3                            Sant Andreu   3.0             54.0
# 4                            Sant Antoni   9.0             16.0
# 5                 Sant Gervasi - Galvany  25.0             14.0
# 6             Sant Gervasi - la Bonanova   3.0             16.0
# 7  Sant Pere, Santa Caterina i la Ribera  33.0             64.0
# 8                                  Sants  10.0             14.0
# 9                                 Sarrià   2.0             26.0
#
#    cinemas_theatres  schools  pre-schools  hospitals  libraries_theatres  \
# 0               3.0     11.0          7.0        3.0                 5.0
# 1               NaN      6.0          3.0        NaN                 NaN
# 2               NaN      8.0         41.0        NaN                10.0
# 3               5.0     22.0         17.0        5.0                 2.0
# 4               4.0     11.0         11.0        1.0                 5.0
# 5               7.0     16.0         17.0        8.0                 9.0
# 6               2.0     19.0         29.0        5.0                 4.0
# 7              11.0      9.0         16.0        1.0                22.0
# 8               4.0     19.0         16.0        4.0                 4.0
# 9               1.0     22.0         25.0        6.0                 5.0
#
#    park_gardens  sport_centers  ...  num_crimes  children_places_pop  \
# 0           3.0            2.0  ...     7.871               0.748643
# 1           NaN            NaN  ...    10.657               0.361517
# 2           9.0            1.0  ...     7.444               1.159324
# 3           5.0            3.0  ...    10.657               0.944337
# 4           7.0            1.0  ...    46.210               0.417264
# 5           9.0            NaN  ...     9.252               0.293710
# 6           7.0            1.0  ...     9.252               0.620781
# 7           2.0            1.0  ...    44.241               2.816777
# 8           6.0            1.0  ...    20.219               0.340409
# 9          11.0            3.0  ...     9.252               1.038671
#
#    cinemas_theatres_pop schools_pop  pre-schools_pop hospitals_pop  \
# 0              0.112296    0.411754         0.262025      0.112296
# 1                   NaN    0.271137         0.135569           NaN
# 2                   NaN    0.662471         3.395164           NaN
# 3              0.087439    0.384730         0.297291      0.087439
# 4              0.104316    0.286869         0.286869      0.026079
# 5              0.146855    0.335669         0.356648      0.167835
# 6              0.077598    0.737177         1.125165      0.193994
# 7              0.484134    0.396109         0.704194      0.044012
# 8              0.097260    0.461984         0.389039      0.097260
# 9              0.039949    0.878875         0.998722      0.239693
#
#   libraries_theatres_pop park_gardens_pop  sport_centers_pop  facilities_pop
# 0               0.187161         0.112296           0.074864        0.219914
# 1                    NaN              NaN                NaN             NaN
# 2               0.828089         0.745280           0.082809             NaN
# 3               0.034975         0.087439           0.052463        0.209853
# 4               0.130395         0.182553           0.026079        0.146694
# 5               0.188814         0.188814                NaN             NaN
# 6               0.155195         0.271592           0.038799        0.261892
# 7               0.968267         0.088024           0.044012        0.605167
# 8               0.097260         0.145890           0.024315        0.158047
# 9               0.199744         0.439438           0.119847        0.369527
#
# [10 rows x 27 columns]

# %% [raw]
# Complete=Complete.drop(["Unnamed: 0"],axis=1)

# %%
#Make a copy to modify stuff
Complete.to_csv("../datasets/Data_filtered/Analysis_M.csv",index=False)

# %%
#Import Copy
Analysis=pd.read_csv("../datasets/Data_filtered/Analysis_M.csv")

# %%
Analysis.columns
# Out:
# Index(['nbh', 'bars', 'children_places', 'cinemas_theatres', 'schools',
#        'pre-schools', 'hospitals', 'libraries_theatres', 'park_gardens',
#        'sport_centers', 'population', 'net_density(hab/ha)', 'avg_occupation',
#        'dist', 'num_immi', 'mort_rate', 'rent_price', 'num_crimes',
#        'children_places_pop', 'cinemas_theatres_pop', 'schools_pop',
#        'pre-schools_pop', 'hospitals_pop', 'libraries_theatres_pop',
#        'park_gardens_pop', 'sport_centers_pop', 'facilities_pop'],
#       dtype='object')

# %%
#Creation of a dataset with lesser features
#Analysis=Analysis.drop(['children_places_pop', 'cinemas_theatres_pop', 'schools_pop',
#       'pre-schools_pop', 'hospitals_pop', 'libraries_theatres_pop',
#       'park_gardens_pop', 'sport_centers_pop', 'facilities_pop'], axis=1)

# %%
#changing the variables order

Analysis=Analysis[['dist','nbh','population', 'net_density(hab/ha)','num_immi',
                  'bars', 'children_places','cinemas_theatres', 'schools','pre-schools',
                  'hospitals', 'libraries_theatres','park_gardens','sport_centers',
                  'avg_occupation','mort_rate', 'rent_price', 'num_crimes']]

# %%
Analysis.rename(columns={libraries_theatres})

# %%
Analysis.head(15)
# Out:
#                    dist                                    nbh  population  \
# 0        Horta-Guinardó                                  Horta     26715.0
# 1           Sant Andreu                                  Navas     22129.0
# 2             Les Corts                              Pedralbes     12076.0
# 3           Sant Andreu                            Sant Andreu     57183.0
# 4              Eixample                            Sant Antoni     38345.0
# 5   Sarrià-Sant Gervasi                 Sant Gervasi - Galvany     47666.0
# 6   Sarrià-Sant Gervasi             Sant Gervasi - la Bonanova     25774.0
# 7          Ciutat Vella  Sant Pere, Santa Caterina i la Ribera     22721.0
# 8        Sants-Montjuïc                                  Sants     41127.0
# 9   Sarrià-Sant Gervasi                                 Sarrià     25032.0
# 10         Ciutat Vella                         el Barri Gòtic     16062.0
# 11               Gràcia     el Camp d'en Grassot i Gràcia Nova     34329.0
# 12          Sant Andreu               el Congrés i els Indians     14116.0
# 13             Eixample                          el Fort Pienc     32016.0
# 14       Horta-Guinardó                            el Guinardó     36467.0
#
#     net_density(hab/ha)  num_immi  bars  children_places  cinemas_theatres  \
# 0                 422.0    1127.0   4.0             20.0               3.0
# 1                 984.0     988.0   2.0              8.0               NaN
# 2                 147.0     764.0   1.0             14.0               NaN
# 3                 746.0    1965.0   3.0             54.0               5.0
# 4                 928.0    2490.0   9.0             16.0               4.0
# 5                 499.0    2434.0  25.0             14.0               7.0
# 6                 314.0    1181.0   3.0             16.0               2.0
# 7                 700.0    2765.0  33.0             64.0              11.0
# 8                 740.0    2839.0  10.0             14.0               4.0
# 9                 260.0    1208.0   2.0             26.0               1.0
# 10                471.0    2687.0  29.0              6.0               5.0
# 11                891.0    1791.0   1.0              8.0               1.0
# 12                737.0     603.0   1.0             20.0               1.0
# 13                959.0    2237.0   4.0             10.0               3.0
# 14                699.0    1837.0   1.0             32.0               NaN
#
#     schools  pre-schools  hospitals  libraries_theatres  park_gardens  \
# 0      11.0          7.0        3.0                 5.0           3.0
# 1       6.0          3.0        NaN                 NaN           NaN
# 2       8.0         41.0        NaN                10.0           9.0
# 3      22.0         17.0        5.0                 2.0           5.0
# 4      11.0         11.0        1.0                 5.0           7.0
# 5      16.0         17.0        8.0                 9.0           9.0
# 6      19.0         29.0        5.0                 4.0           7.0
# 7       9.0         16.0        1.0                22.0           2.0
# 8      19.0         16.0        4.0                 4.0           6.0
# 9      22.0         25.0        6.0                 5.0          11.0
# 10      5.0         10.0        1.0                23.0           2.0
# 11     10.0          9.0        2.0                 1.0           3.0
# 12     11.0          5.0        NaN                 1.0           2.0
# 13      9.0          6.0        2.0                 5.0           8.0
# 14     13.0         12.0        2.0                 6.0          10.0
#
#     sport_centers  avg_occupation mort_rate rent_price num_crimes
# 0             2.0             2.5     805,5       2.97    7.871
# 1             NaN             2.5     696,0      3.029   10.657
# 2             1.0             2.9     661,6       6.34    7.444
# 3             3.0             2.4     763,0       3.21   10.657
# 4             1.0             2.3     737,3      4.591   46.210
# 5             NaN             2.6     716,1      5.306    9.252
# 6             1.0             2.8     775,5      5.029    9.252
# 7             1.0             2.3     911,4      5.152   44.241
# 8             1.0             2.4     782,1      3.666   20.219
# 9             3.0             2.8     758,7      6.042    9.252
# 10            2.0             2.5   1.004,5      4.884   44.241
# 11            4.0             2.3     821,6      4.391    7.731
# 12            NaN             2.4     748,5       n.d.   10.657
# 13            1.0             2.5     807,6      4.107   46.210
# 14            1.0             2.4     733,8      3.164    7.871

# %%
#Step 1: Define Nbh quality
#Are there facilities more valuable than others?:
#top 5 for each facility
#worst 5
#top 5 Nbh and Dist with higher number of facilities
#worst 5

# %%
Analysis["dist"].describe()
#There are 10 dist
# Out:
# count             73
# unique            10
# top       Nou Barris
# freq              13
# Name: dist, dtype: object

# %%
Analysis["mort_rate"].astype("float")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-2245f7ad96e1> in <module>
# ----> 1 Analysis["mort_rate"].astype("float")
#
# /usr/local/Cellar/jupyterlab/2.1.4/libexec/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# /usr/local/Cellar/jupyterlab/2.1.4/libexec/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# /usr/local/Cellar/jupyterlab/2.1.4/libexec/lib/python3.8/site-packages/pandas/core/internals/managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# /usr/local/Cellar/jupyterlab/2.1.4/libexec/lib/python3.8/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     623             vals1d = values.ravel()
#     624             try:
# --> 625                 values = astype_nansafe(vals1d, dtype, copy=True)
#     626             except (ValueError, TypeError):
#     627                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# /usr/local/Cellar/jupyterlab/2.1.4/libexec/lib/python3.8/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     895     if copy or is_object_dtype(arr) or is_object_dtype(dtype):
#     896         # Explicit copy, or required since NumPy can't view from / to object.
# --> 897         return arr.astype(dtype, copy=True)
#     898
#     899     return arr.view(dtype)
#
# ValueError: could not convert string to float: '805,5'

# %%
Analysis.dtypes
# Out:
# dist                    object
# nbh                     object
# population             float64
# net_density(hab/ha)    float64
# num_immi               float64
# bars                   float64
# children_places        float64
# cinemas_theatres       float64
# schools                float64
# pre-schools            float64
# hospitals              float64
# libraries_theatres     float64
# park_gardens           float64
# sport_centers          float64
# avg_occupation         float64
# mort_rate               object
# rent_price              object
# num_crimes              object
# dtype: object

# %%
#Information by dist (rounded)

MeanDist=Analysis.groupby("dist").aggregate({"mean"}).round(decimals=3)

# %%
MeanDist.head()
MeanDist.columns
# Out:
# MultiIndex([(         'population', 'mean'),
#             ('net_density(hab/ha)', 'mean'),
#             (           'num_immi', 'mean'),
#             (               'bars', 'mean'),
#             (    'children_places', 'mean'),
#             (   'cinemas_theatres', 'mean'),
#             (            'schools', 'mean'),
#             (        'pre-schools', 'mean'),
#             (          'hospitals', 'mean'),
#             ( 'libraries_theatres', 'mean'),
#             (       'park_gardens', 'mean'),
#             (      'sport_centers', 'mean'),
#             (     'avg_occupation', 'mean')],
#            )

# %%
MeanDist=MeanDist[['population', 'net_density(hab/ha)', 'num_immi', 'bars',
       'children_places', 'cinemas_theatres', 'schools', 'pre-schools',
       'hospitals', 'libraries_theatres', 'park_gardens', 'sport_centers',
       'avg_occupation', 'mort_rate', 'rent_price', 'num_crimes']]
# Out:
# MultiIndex([(         'population', 'mean'),
#             ('net_density(hab/ha)', 'mean'),
#             (           'num_immi', 'mean'),
#             (               'bars', 'mean'),
#             (    'children_places', 'mean'),
#             (   'cinemas_theatres', 'mean'),
#             (            'schools', 'mean'),
#             (        'pre-schools', 'mean'),
#             (          'hospitals', 'mean'),
#             ( 'libraries_theatres', 'mean'),
#             (       'park_gardens', 'mean'),
#             (      'sport_centers', 'mean'),
#             (     'avg_occupation', 'mean')],
#            )
