# %%
import pandas as pd
import numpy as np
import os

# %%
csv_holidays = pd.read_csv("datasets/1.-Transportation/holidays.csv")
csv_holidays
# Out:
#      Unnamed: 0               Id   District Name  \
# 0           162  2017S005486        Ciutat Vella
# 1           284  2017S005492            Eixample
# 2           411  2017S005488            Eixample
# 3           577  2017S005505            Eixample
# 4           730  2017S005504      Sants-Montjuïc
# ..          ...              ...             ...
# 351        6984  2017S000016            Eixample
# 352        9164  2017S000017          Sant Martí
# 353        9171  2017S000019          Sant Martí
# 354        9187  2017S000005          Sant Martí
# 355        9244  2017S000011          Sant Martí
#
#                      Neighborhood Name  \
# 0                             el Raval
# 1       la Nova Esquerra de l'Eixample
# 2      l'Antiga Esquerra de l'Eixample
# 3               la Dreta de l'Eixample
# 4                la Font de la Guatlla
# ..                                 ...
# 351                      el Fort Pienc
# 352            Provençals del Poblenou
# 353                        el Poblenou
# 354  el Parc i la Llacuna del Poblenou
# 355      la Vila Olímpica del Poblenou
#
#                                                 Street Weekday    Month  Day  \
# 0    Nou de la Rambla                              ...  Friday     June   23
# 1    València                                      ...  Friday     June   23
# 2    Aragó                                         ...  Friday     June   23
# 3    Roger de Llúria / Corts Catalanes             ...  Friday     June   23
# 4    Corts Catalanes                               ...  Friday     June   23
# ..                                                 ...     ...      ...  ...
# 351  MARINA                                        ...  Sunday  January    1
# 352  CTRA C-31                                     ...  Sunday  January    1
# 353  ESPRONCEDA                                    ...  Sunday  January    1
# 354  PALLARS                                       ...  Sunday  January    1
# 355  AV LITORAL                                    ...  Sunday  January    1
#
#      Hour Part of the day  Mild injuries  Serious injuries  Victims  \
# 0       1           Night              1                 0        1
# 1      10         Morning              1                 0        1
# 2       9         Morning              1                 0        1
# 3      16       Afternoon              1                 0        1
# 4      17       Afternoon              2                 0        2
# ..    ...             ...            ...               ...      ...
# 351    16       Afternoon              1                 0        1
# 352    19       Afternoon              2                 0        2
# 353    19       Afternoon              1                 0        1
# 354     7         Morning              2                 0        2
# 355    15       Afternoon              1                 0        1
#
#      Vehicles involved  Longitude   Latitude
# 0                    1   2.170537  41.375415
# 1                    2   2.149208  41.381935
# 2                    2   2.161160  41.389575
# 3                    2   2.170988  41.391485
# 4                    1   2.145781  41.372183
# ..                 ...        ...        ...
# 351                  1   2.181480  41.398601
# 352                  2   2.203262  41.415467
# 353                  1   2.206838  41.403515
# 354                  3   2.193249  41.397908
# 355                  2   2.201548  41.391097
#
# [356 rows x 16 columns]

# %%
csv_without_holidays = pd.read_csv("datasets/1.-Transportation/accidents-without-holidays.csv")
csv_without_holidays
# Out:
#       Unnamed: 0 District Name    Weekday      Month  Day Part of the day  \
# 0              0       Unknown     Friday    October   13         Morning
# 1              1       Unknown     Friday  September    1         Morning
# 2              3       Unknown     Friday       July   21           Night
# 3              4    Sant Martí   Thursday        May   25       Afternoon
# 4              5    Sant Martí  Wednesday  September   20         Morning
# ...          ...           ...        ...        ...  ...             ...
# 9978       10334   Sant Andreu    Tuesday      April   25         Morning
# 9979       10335   Sant Andreu  Wednesday      March    8         Morning
# 9980       10336   Sant Andreu   Thursday   December   28         Morning
# 9981       10337   Sant Andreu     Friday       July   14       Afternoon
# 9982       10338   Sant Andreu     Sunday    January    8       Afternoon
#
#       Mild injuries  Serious injuries  Victims  Vehicles involved
# 0                 2                 0        2                  2
# 1                 2                 0        2                  2
# 2                 1                 0        1                  2
# 3                 1                 0        1                  3
# 4                 1                 0        1                  2
# ...             ...               ...      ...                ...
# 9978              1                 0        1                  3
# 9979              1                 0        1                  2
# 9980              1                 0        1                  2
# 9981              1                 0        1                  2
# 9982              0                 0        0                  1
#
# [9983 rows x 10 columns]

# %%
original_file = pd.read_csv("datasets/1.-Transportation/accidents-2017.csv")
original_file
# Out:
#                     Id District Name           Neighborhood Name  \
# 0      2017S008429           Unknown                     Unknown
# 1      2017S007316           Unknown                     Unknown
# 2      2017S010210           Unknown                     Unknown
# 3      2017S006364           Unknown                     Unknown
# 4      2017S004615        Sant Martí  el Camp de l'Arpa del Clot
# ...                ...           ...                         ...
# 10334  2017S003667       Sant Andreu               el Bon Pastor
# 10335  2017S001896       Sant Andreu               el Bon Pastor
# 10336  2017S010718       Sant Andreu               el Bon Pastor
# 10337  2017S006145       Sant Andreu               el Bon Pastor
# 10338  2017S000178       Sant Andreu               el Bon Pastor
#
#                                                   Street    Weekday  \
# 0      Número 27                                     ...     Friday
# 1      Número 3 Zona Franca / Número 50 Zona Franca  ...     Friday
# 2      Litoral (Besòs)                               ...     Friday
# 3      Número 3 Zona Franca                          ...     Friday
# 4      Las Navas de Tolosa                           ...   Thursday
# ...                                                  ...        ...
# 10334  Litoral (Llobregat)                           ...    Tuesday
# 10335  PL MONTERREY                                  ...  Wednesday
# 10336  Litoral (Llobregat)                           ...   Thursday
# 10337  Litoral (Besòs)                               ...     Friday
# 10338  CIUTAT D'ASUNCIÓN                             ...     Sunday
#
#            Month  Day  Hour Part of the day  Mild injuries  Serious injuries  \
# 0        October   13     8         Morning              2                 0
# 1      September    1    13         Morning              2                 0
# 2       December    8    21       Afternoon              5                 0
# 3           July   21     2           Night              1                 0
# 4            May   25    14       Afternoon              1                 0
# ...          ...  ...   ...             ...            ...               ...
# 10334      April   25     8         Morning              1                 0
# 10335      March    8    12         Morning              1                 0
# 10336   December   28     8         Morning              1                 0
# 10337       July   14    14       Afternoon              1                 0
# 10338    January    8    20       Afternoon              0                 0
#
#        Victims  Vehicles involved  Longitude   Latitude
# 0            2                  2   2.125624  41.340045
# 1            2                  2   2.120452  41.339426
# 2            5                  2   2.167356  41.360885
# 3            1                  2   2.124529  41.337668
# 4            1                  3   2.185272  41.416365
# ...        ...                ...        ...        ...
# 10334        1                  3   2.201800  41.392004
# 10335        1                  2   2.206013  41.443445
# 10336        1                  2   2.205607  41.443894
# 10337        1                  2   2.205118  41.444824
# 10338        0                  1   2.200956  41.437125
#
# [10339 rows x 15 columns]
